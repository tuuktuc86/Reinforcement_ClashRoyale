# %%
#일정량 이상의 마이너스 값이 들어가면 그거 학습 안시킬 것임.

k fold? 만큼 학습시킬것.
그다음? 카드 클릭하고 화면 클릭하는 경우만 가능하게 하고 그렇게 안했을 경우 train dataset에 넣지 말것.

# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import collections
import random
import matplotlib.pyplot as plt
import pyautogui as pag
import PIL
import torchvision.transforms as transforms
import cv2
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from PIL import Image
import time
import seaborn as sns
from torch.distributions import Categorical

pag.FAILSAFE = False


import argparse
import torch

import torch.multiprocessing as _mp
from torch.distributions import Categorical
import torch.nn.functional as F



import numpy as np
import shutil
from torch.utils.tensorboard import SummaryWriter


from random import sample

# %%
import warnings

warnings.filterwarnings(action='ignore')

# %%
#env.py
class ENV():
    def __init__(self):
        # screenshot의 위치 지정, 클래스 생성할때 가져오기

        # winflg와 lose flag 존재해야 함. 0으로 하는 건 grayscale
        self.winFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/weWin.png', 0)
        self.loseFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemyWin.png', 0)
        # nocard flag
        self.nocardFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/nocard.png')
        # noElixir flag
        self.noelixirFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/noElixir.png')
        self.startGameFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/battleStart.png')
        self.finishFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/battleFinish.png')
        self.enemy1Flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemy1.png')
        self.enemy2Flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemy2.png')
        self.enemy3Flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemy3.png')
        self.stop_flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/stop_game_full.png')
        self.main_flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/main_check.png')
        
    def return_state(self, img):
        # 스크린 샷을 인자로 받아와서 모델에 넣을 수 있도록 tensor로 변환
        tf = transforms.ToTensor()
        img_t = tf(img) # time.sleep(0.3)
        img_t = img_t.unsqueeze(0)
        # img_t = img_t.permute(1, 0, 2, 3)

        return img_t

    def check_finish(self,img):
        finishMessage = cv2.cvtColor(self.finishFlag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(finishMessage, img, cv2.TM_CCOEFF_NORMED)
        if (np.max(ratio) > 0.90):
            return 1

        else:
            return 0

    def check_win(self, img):
        # 게임이 이겼는지 확인, screenshot을 가져와서 우리가 원하는 크기로 잘라서 확인
        # img = np.array(img)
        checkFlag1 = np.array(img.crop((225, 335, 280, 365)))
        checkFlag1 = cv2.cvtColor(checkFlag1, cv2.COLOR_BGR2GRAY)
        win_check = cv2.matchTemplate(checkFlag1, self.winFlag, cv2.TM_CCOEFF_NORMED)
        if win_check > 0.8:
            return 1

        else:
            return 0
           
    def check_lose(self, img):
        # 게임이 졌는지 확인, screenshot을 가져와서 우리가 원하는 크기로 잘라서 확인
        # img = np.array(img)
        checkFlag2 = np.array(img.crop((225, 85, 280, 115)))
        checkFlag2 = cv2.cvtColor(checkFlag2, cv2.COLOR_BGR2GRAY)
        lose_check = cv2.matchTemplate(checkFlag2, self.loseFlag, cv2.TM_CCOEFF_NORMED)
        if lose_check > 0.8:
            return 1

        else:
            return 0

    def check_card(self, img):
        # 카드를 선택하지 않았는지 확인, screenshot을 가져와서 init에 지정된 nocard 이미지와 비교하여 reward 부여
        nocard = cv2.cvtColor(self.nocardFlag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(nocard, img, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0

    def check_elixir(self, img):
        noElixir = cv2.cvtColor(self.noelixirFlag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(noElixir, img, cv2.TM_CCOEFF_NORMED)

        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0

    def checkET1(self, img):
        score1 = 0
        checkFlag1 = np.array(img.crop((105, 135, 155, 136)))

        for i in range(50):
            if (checkFlag1[0][i][0] >= 96):
                score1 += 1

        score1 = score1 * 2
        return score1

    def checkET2(self, img):
        score2 = 0
        checkFlag2 = np.array(img.crop((371, 135, 421, 136)))

        for i in range(50):
            if (checkFlag2[0][i][0] >= 96):
                score2 += 1

        score2 = score2 * 2
        return score2

    def checkGameStart(self, img):
        startMessage = cv2.cvtColor(self.startGameFlag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(startMessage, img, cv2.TM_CCOEFF_NORMED)
        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0
        
    def checkMainPage(self, img):
        main_check = cv2.cvtColor(self.main_flag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(main_check, img, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0
        
    def stop_game(self, img):
        stopMessage = cv2.cvtColor(self.stop_flag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(stopMessage, img, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0

    def enemy1(self, img):
        crownFlag1 = cv2.cvtColor(self.enemy1Flag, cv2.COLOR_BGR2GRAY)
        img1 = np.array(img)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(crownFlag1, img1, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            return 1
        else:
            return 0
        
    def enemy2(self, img):
        crownFlag2 = cv2.cvtColor(self.enemy2Flag, cv2.COLOR_BGR2GRAY)
        img1 = np.array(img)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(crownFlag2, img1, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            return 1
        else:
            return 0
        
    def enemy3(self, img):
        crownFlag3 = cv2.cvtColor(self.enemy3Flag, cv2.COLOR_BGR2GRAY)
        img1 = np.array(img)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(crownFlag3, img1, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            return 1
        else:
            return 0

    # def checkOT1
    # def checkOT1
    # def checkOT1

    # 우리 타워와 상대 타워의 hp를 확인하여 reward 부여

    def retryGame(self):
        time.sleep(8)
        pag.click((2860, 875))
        #print("step1 click")
        time.sleep(5)
        
        while(1):
            img = pag.screenshot(region=(2605, 100, 510, 900))
            if(self.checkMainPage(img)):
                break
            time.sleep(5)
                
        pag.click((3070, 185))
        time.sleep(5)
        pag.click((2920, 385))
        time.sleep(3)
        pag.click((2950, 615))

# %%
learning_rate = 0.0001
gamma = 0.98
lmbda = 0.95
eps_clip = 0.1
K_epoch = 1
T_horizon = 1
delay_time = 0.3

# %%
#model.py
class PPO(nn.Module):
    def __init__(self, num_actions):
        super(PPO, self).__init__()
        
        self.data = []
        
        self.conv1 = nn.Sequential(nn.Conv2d(3, 16, 3, stride=2, padding=1),
                                   # nn.BatchNorm2d(16),
                                   nn.ReLU(inplace=True))
        self.conv2 = nn.Sequential(nn.Conv2d(16, 32, 3, stride=2, padding=1),
                                   nn.BatchNorm2d(32),
                                   nn.ReLU(inplace=True))
        self.conv3 = nn.Sequential(nn.Conv2d(32, 64, 3, stride=2, padding=1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU(inplace=True))
        self.avgpool = nn.AdaptiveAvgPool2d(1)
        self.actor_linear = nn.Sequential(nn.Linear(64, 64),
                                          nn.ReLU(inplace=True),
                                          nn.Linear(64, num_actions))
        self.critic_linear = nn.Sequential(nn.Linear(64, 64),
                                          nn.ReLU(inplace=True),
                                          nn.Linear(64, 1))
        self.optimizer = optim.Adam(self.parameters(), lr = learning_rate)
    
    def pi(self, x, softmax_dim = 0):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        # x = self.actor_linear(x.reshape(x.size(0), -1))
        x = self.avgpool(x).reshape(x.size(0), -1)
        x = self.actor_linear(x)
        prob = F.softmax(x, dim = softmax_dim)
        return prob
    
    def v(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.avgpool(x).reshape(x.size(0), -1)
        v = self.critic_linear(x.reshape(x.size(0), -1))
        return v
    
    def put_data(self, transition):
        self.data.append(transition)
        
    def clear_data(self):
        self.data = []
        
    def make_batch(self):
        s_lst, a_lst, r_lst, s_prime_lst, prob_a_lst, done_lst = [], [], [], [], [], []
        
        for transition in self.data:
            s, a, r, s_prime, prob_a, done = transition
             
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            prob_a_lst.append(prob_a)
            done_mask = 0 if done else 1
            done_lst.append([done_mask])
            
#         s_lst1 = np.array(s_lst)
#         s_prime_lst1 = np.array(s_prime_lst)
#         print(s_lst1.shape)
#         print(s_prime_lst1.shape)
        
        
        s_lst = torch.stack(s_lst).cuda()
        s_prime_lst = torch.stack(s_prime_lst).cuda()
        
#         print("s_lst")
#         print(s_lst[0])
#         print("s_prime_lst")
#         print(s_prime_lst[0])
        s_lst = torch.tensor(s_lst[0]).cuda()
        s_prime_lst = torch.tensor(s_prime_lst[0]).cuda()
        #print(f"type_slst = {type(s_lst)}")
        s,a,r,s_prime,done_mask, prob_a = s_lst, torch.tensor(a_lst).cuda(), \
                                          torch.tensor(r_lst).cuda(), s_prime_lst, \
                                          torch.tensor(done_lst, dtype=torch.float).cuda(), torch.tensor(prob_a_lst).cuda()
#         print("111111111")
#         print(s.shape)
#         print("222222222")
#         print(s_prime.shape)
#         s = s.squeeze()
#         s_prime = s_prime.squeeze()
        s, s_prime, = s.cuda(), s_prime.cuda() 
        self.data = []
        return s, a, r, s_prime, done_mask, prob_a
            
    def train_net(self):
        s, a, r, s_prime, done_mask, prob_a = self.make_batch()
        #print(f"s size = {len(s)}, s_prime_size - {len(s_prime)}")
        
        global train_time
        #print(f"a = {a}")
        for i in range(K_epoch):
            train_time += 1
#             print("s_prime")
#             print(s_prime)
#             print(s_prime.shape)
#             print("s")
#             print(s)
#             print(s.shape)
            
            td_target = r + gamma * self.v(s_prime) * done_mask
            delta = td_target - self.v(s)
            delta = delta.to("cpu")
            delta = delta.detach().numpy()           
            advantage_lst = []
            advantage = 0.0
            for delta_t in delta[::-1]:
                advantage = gamma * lmbda * advantage + delta_t[0]
                advantage_lst.append([advantage])
            advantage_lst.reverse()
            advantage = torch.tensor(advantage_lst, dtype = torch.float).cuda()
            
            pi = self.pi(s, softmax_dim = 1)
            pi_a = pi.gather(1, a)
            #print(f"pi_a = {pi_a}, prob_A = {prob_a}")
            ratio = torch.exp(torch.log(pi_a) - torch.log(prob_a))
            surr1 = ratio * advantage
            surr2 = torch.clamp(ratio, 1-eps_clip, 1+eps_clip) * advantage
            #print(f"advantage = {advantage}")
            #print("=================")
            #print(f"surr1 = {surr1}, surr2 = {surr2}")
            loss = -torch.min(surr1, surr2) + F.smooth_l1_loss(self.v(s), td_target.detach())
            #print(f"loss1 = {loss.mean()}")
            writer.add_scalar("Loss/train", loss.mean(), train_time)
            writer.flush()
            self.optimizer.zero_grad()
            loss.mean().backward()
            #loss.backward()
            self.optimizer.step()
            if(train_time%100 == 0):
                print(f"{train_time} train is over")

# %%
#train.py envs = MultipleEnvironments(opt.world, opt.stage, opt.action_type, opt.num_processes)
env = ENV()

# %%
#train.py model = PPO(envs.num_states, envs.num_actions)
model = PPO(45).cuda()

# %%
PATH= "trained_models/clash_royale_PPO_v212000"

# %%
model.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
#           [ 1.5916e-01,  5.2661e-02, -2.2412e-03],
#           [ 1.6540e-01, -5.0770e-02, -4.3936e-02]],
#
#          [[ 4.0877e-03, -1.3950e-01, -1.8389e-01],
#           [-5.3554e-02, -2.2063e-02,  6.6641e-04],
#           [-1.0645e-01, -9.0543e-02,  2.4571e-02]]]], device='cuda:0',
#        requires_grad=True)
# Parameter containing:
# tensor([-0.1185,  0.0513, -0.0757,  0.1571, -0.1726,  0.0475,  0.1721,  0.0559,
#          0.1201, -0.1702,  0.1024,  0.0232, -0.1218, -0.1422,  0.0980,  0.0884],
#        device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[[[-0.0019, -0.0211,  0.0457],
#           [-0.0210, -0.0240,  0.0414],
#           [-0.0757, -0.0790, -0.0800]],
#
#          [[-0.0088, -0.0266,  0.0477],
#           [-0.0568,  0.0688,  0.0773],
#           [-0.0417, -0.0052, -0.0462]],
#
#          [[-0.0147,  0.0571,  0.0139],
#           [ 0.0597, -0.0641, -0.0200],
#           [ 0.0142, -0.0296, -0.0759]],
#
#          ...,
#
#          [[ 0.0703, -0.0819,  0.0546],
#           [ 0.0693,  0.0352,  0.0266],
#           [ 0.0567,  0.0178, -0.0070]],
#
#          [[ 0.0024, -0.0108,  0.0635],
#           [-0.0180,  0.0273,  0.0719],
#           [ 0.0198,  0.0546,  0.0445]],
#
#          [[ 0.0562, -0.0706,  0.0460],
#           [ 0.0289, -0.0257, -0.0747],
#           [ 0.0073, -0.0607, -0.0119]]],
#
#
#         [[[ 0.0219, -0.0487,  0.0068],
#           [ 0.0583, -0.0465,  0.0801],
#           [ 0.0816,  0.0038,  0.0789]],
#
#          [[-0.0503, -0.0196, -0.0469],
#           [ 0.0730,  0.0302, -0.0803],
#           [-0.0700, -0.0661,  0.0140]],
#
#          [[ 0.0363, -0.0201,  0.0628],
#           [ 0.0006, -0.0025,  0.0660],
#           [-0.0829, -0.0245,  0.0546]],
#
#          ...,
#
#          [[ 0.0048, -0.0130,  0.0804],
#           [-0.0691, -0.0734,  0.0205],
#           [-0.0304, -0.0378, -0.0624]],
#
#          [[ 0.0153, -0.0295,  0.0681],
#           [-0.0494, -0.0092, -0.0339],
#           [-0.0358, -0.0607, -0.0619]],
#
#          [[-0.0790,  0.0156, -0.0800],
#           [ 0.0567,  0.0365, -0.0307],
#           [ 0.0640, -0.0370, -0.0067]]],
#
#
#         [[[-0.0319,  0.0691,  0.0809],
#           [-0.0212, -0.0822,  0.0819],
#           [-0.0199, -0.0140, -0.0545]],
#
#          [[ 0.0215, -0.0298, -0.0709],
#           [ 0.0405,  0.0371,  0.0020],
#           [ 0.0169, -0.0758,  0.0389]],
#
#          [[-0.0358,  0.0255,  0.0828],
#           [ 0.0490, -0.0392,  0.0202],
#           [-0.0285,  0.0664,  0.0282]],
#
#          ...,
#
#          [[-0.0670,  0.0035, -0.0818],
#           [-0.0780, -0.0604,  0.0254],
#           [-0.0541,  0.0418,  0.0804]],
#
#          [[-0.0283,  0.0772,  0.0764],
#           [-0.0565,  0.0011,  0.0558],
#           [-0.0328,  0.0509, -0.0241]],
#
#          [[-0.0693, -0.0239, -0.0669],
#           [ 0.0125, -0.0156, -0.0659],
#           [-0.0243,  0.0125,  0.0247]]],
#
#
#         ...,
#
#
#         [[[ 0.0739,  0.0729, -0.0410],
#           [ 0.0799, -0.0008, -0.0524],
#           [ 0.0190,  0.0263, -0.0397]],
#
#          [[ 0.0449, -0.0379,  0.0487],
#           [ 0.0736, -0.0532, -0.0022],
#           [ 0.0188,  0.0744, -0.0334]],
#
#          [[ 0.0524,  0.0453,  0.0831],
#           [-0.0619,  0.0273, -0.0794],
#           [ 0.0730,  0.0134,  0.0363]],
#
#          ...,
#
#          [[ 0.0517,  0.0691,  0.0061],
#           [ 0.0297, -0.0749, -0.0421],
#           [ 0.0822,  0.0343, -0.0827]],
#
#          [[-0.0305, -0.0086,  0.0137],
#           [ 0.0728, -0.0290,  0.0448],
#           [ 0.0492, -0.0129, -0.0077]],
#
#          [[ 0.0131,  0.0595,  0.0575],
#           [ 0.0470,  0.0517, -0.0776],
#           [ 0.0696, -0.0008, -0.0105]]],
#
#
#         [[[-0.0166, -0.0228,  0.0308],
#           [-0.0107,  0.0792,  0.0247],
#           [ 0.0101, -0.0261, -0.0721]],
#
#          [[-0.0418, -0.0170, -0.0779],
#           [-0.0794,  0.0297,  0.0189],
#           [ 0.0028,  0.0160, -0.0211]],
#
#          [[-0.0615, -0.0745,  0.0195],
#           [ 0.0027, -0.0629, -0.0280],
#           [ 0.0302,  0.0493,  0.0025]],
#
#          ...,
#
#          [[-0.0560, -0.0188,  0.0248],
#           [ 0.0004, -0.0555,  0.0749],
#           [-0.0074, -0.0105, -0.0650]],
#
#          [[ 0.0659,  0.0666, -0.0118],
#           [-0.0560, -0.0211, -0.0629],
#           [ 0.0413,  0.0567, -0.0776]],
#
#          [[ 0.0117, -0.0712, -0.0148],
#           [-0.0498,  0.0371, -0.0422],
#           [ 0.0146,  0.0817,  0.0519]]],
#
#
#         [[[-0.0253,  0.0081, -0.0366],
#           [-0.0159, -0.0082, -0.0187],
#           [ 0.0348,  0.0215,  0.0661]],
#
#          [[-0.0580, -0.0310,  0.0016],
#           [-0.0231,  0.0830,  0.0559],
#           [-0.0745,  0.0783, -0.0553]],
#
#          [[ 0.0077, -0.0509, -0.0735],
#           [ 0.0569,  0.0408,  0.0091],
#           [-0.0569,  0.0822,  0.0100]],
#
#          ...,
#
#          [[ 0.0679, -0.0499, -0.0267],
#           [ 0.0300, -0.0450, -0.0759],
#           [ 0.0734, -0.0740,  0.0505]],
#
#          [[ 0.0143, -0.0416,  0.0164],
#           [ 0.0520, -0.0166,  0.0055],
#           [-0.0024, -0.0591, -0.0427]],
#
#          [[ 0.0372,  0.0342, -0.0777],
#           [-0.0699,  0.0383, -0.0632],
#           [-0.0399, -0.0759,  0.0283]]]], device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([

#        device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([[ 0.0987,  0.0531, -0.0766, -0.1139, -0.0756,  0.0197, -0.0947,  0.0367,
#           0.0187, -0.0233, -0.0034,  0.0374,  0.0139,  0.0619, -0.1059, -0.0460,
#           0.0367,  0.0336, -0.0524,  0.0073,  0.0733,  0.0015,  0.0800, -0.0022,
#          -0.0830, -0.0316, -0.1098,  0.0852,  0.0405,  0.0689, -0.0732,  0.0597,
#           0.1183, -0.0030,  0.1177,  0.0468, -0.0301,  0.0510, -0.0493,  0.1192,
#           0.1152, -0.0453,  0.0738,  0.0010,  0.0525, -0.0470,  0.0776,  0.0793,
#          -0.1206,  0.0950,  0.0876,  0.0522,  0.0310,  0.0578,  0.0724, -0.0141,
#           0.0862,  0.0659, -0.1010, -0.0724,  0.0302, -0.0187, -0.1154, -0.0287]],
#        device='cuda:0', requires_grad=True)
# Parameter containing:
# tensor([-0.0051], device='cuda:0', requires_grad=True)

# %%
action_list = []
action_list_name = {}
count = 0
for i in range(5):
    for j in range(8):
        action_list.append((2655+j*58.571, 510+i*63.75))
        
        action_list_name[count] = str(i) + ' ' + str(j)
        count+=1
        
action_list.append([2765, 900])
action_list.append([2855, 940])
action_list.append([2950, 900])
action_list.append([3055, 900])
action_list.append([-1, -1])
action_list_name[40] = "card 1"
action_list_name[41] = "card 2"
action_list_name[42] = "card 3"
action_list_name[43] = "card 4"
action_list_name[44] = "rest action"

# %%
print(action_list)
print(action_list_name)
# Out:
# [(2655.0, 510.0), (2713.571, 510.0), (2772.142, 510.0), (2830.713, 510.0), (2889.284, 510.0), (2947.855, 510.0), (3006.426, 510.0), (3064.997, 510.0), (2655.0, 573.75), (2713.571, 573.75), (2772.142, 573.75), (2830.713, 573.75), (2889.284, 573.75), (2947.855, 573.75), (3006.426, 573.75), (3064.997, 573.75), (2655.0, 637.5), (2713.571, 637.5), (2772.142, 637.5), (2830.713, 637.5), (2889.284, 637.5), (2947.855, 637.5), (3006.426, 637.5), (3064.997, 637.5), (2655.0, 701.25), (2713.571, 701.25), (2772.142, 701.25), (2830.713, 701.25), (2889.284, 701.25), (2947.855, 701.25), (3006.426, 701.25), (3064.997, 701.25), (2655.0, 765.0), (2713.571, 765.0), (2772.142, 765.0), (2830.713, 765.0), (2889.284, 765.0), (2947.855, 765.0), (3006.426, 765.0), (3064.997, 765.0), [2765, 900], [2855, 940], [2950, 900], [3055, 900], [-1, -1]]
# {0: '0 0', 1: '0 1', 2: '0 2', 3: '0 3', 4: '0 4', 5: '0 5', 6: '0 6', 7: '0 7', 8: '1 0', 9: '1 1', 10: '1 2', 11: '1 3', 12: '1 4', 13: '1 5', 14: '1 6', 15: '1 7', 16: '2 0', 17: '2 1', 18: '2 2', 19: '2 3', 20: '2 4', 21: '2 5', 22: '2 6', 23: '2 7', 24: '3 0', 25: '3 1', 26: '3 2', 27: '3 3', 28: '3 4', 29: '3 5', 30: '3 6', 31: '3 7', 32: '4 0', 33: '4 1', 34: '4 2', 35: '4 3', 36: '4 4', 37: '4 5', 38: '4 6', 39: '4 7', 40: 'card 1', 41: 'card 2', 42: 'card 3', 43: 'card 4', 44: 'rest action'}

# %%
writer = SummaryWriter()

# %%
#train.py curr_episode = 0
curr_episode = 0
train_time = 0
play_time = 0

# %%
while True:
    curr_episode += 1
    
    
    #reward 초기화
    r = 0
    
    #done 초기화
    done = 0
    
    # enemy tower score / score1 = left, score2 = right
    score1 = 100
    score2 = 100
    
    num_local_steps = 0
    
    #set start_flag
    start_flag = 0
    
    #승리 패배를 기록
    win_lose_flag = 0
    
    #s라는 변수는 이렇다는 것을 보여주기 위한 구문
    img = pag.screenshot(region=(2605, 100, 510, 900))
    s = env.return_state(img).cuda()
    right_click_flag = 0
    play_time += 1
    
    card_click_flag = 0
    real_click_flag = 0
    while(1):
    #for _ in range(40):
        #opt 기본 num_local_steps = 512
        
        #게임 시작 확인 전까지 멈춤 지시
        while (start_flag == 0):
            # 스크린샷 찍기
            img = pag.screenshot(region=(2605, 100, 510, 900))
            #time.sleep(0.5)
            if (env.checkGameStart(img)):
                print("game start")
                start_flag = 1
                time.sleep(3)
                #현재 이미지 캡처 후 변환
                img = pag.screenshot(region=(2605, 100, 510, 900))
                s = env.return_state(img).cuda()
                break
                
#         img = pag.screenshot(region=(2605, 100, 510, 900))
#         s = env.return_state(img).cuda()
        
        for t in range(T_horizon):        

            #num_local_step_count
            num_local_steps += 1



            prob = model.pi(s, softmax_dim=1)
            #print(f"prob = {prob}")
            m = Categorical(prob)
            a = m.sample().item()



#             if(a >= 40 and a <= 43):
#                 right_click_flag = 1

#             if(right_click_flag == 1 and a >= 0 and a <= 39):
#                 print("right_click")
#                 r+= 50
#                 right_click_flag = 0

            
            print(f"action = {action_list_name[a]}")
            if(a >= 40 and a <= 43):
                card_click_flag = 1 #card가 선택되면 1
                real_click_flag = 1
            
            if(card_click_flag == 0 and a >= 0 and a <= 39):
                print(f"wrong click")
                a=44
                
            if(card_click_flag == 1 and a >= 0 and a <= 39):
                real_click_flag = 1
                card_click_flag = 0
                #print("you grab it")
                r+=10
                
            
                
            
            
            if(a == 44):
                time.sleep(delay_time)
                
            
            #print(f"a = {a}")
            #pag 클릭. rest action은 -1 -1 이므로 실행하지 않음
            if(a!=44 and real_click_flag == 1):
                # 화면 클릭
                print("click")
                pag.click(action_list[a][0], action_list[a][1])
                time.sleep(delay_time)
                if card_click_flag == 1 and a >= 0 and a <= 39:
                    real_click_flag = 0
                
                
#             if(a!=44):
#                 # 화면 클릭
#                 pag.click(action_list[a][0], action_list[a][1])
#                 time.sleep(0.5)
                


            #클릭 한번당 reward -1
            r -= 1

            # 승리 확인
            if (env.check_win(img)):
                print("win")
                r += 5000
                done = 1
                win_lose_flag = 1

            # 패배 확인
            if (env.check_lose(img)):
                print("lose")
                r -= 5000
                done = 1
                win_lose_flag = -1

            # no card확인
            if (env.check_card(img)):
                r -= 20
                print("no card")

            # no elixir확인
            if (env.check_elixir(img)):
                r -= 100
                print("no Elixir")

            if (env.enemy1(img)):
                r -= 100
                print("crown - 1")

            if (env.enemy2(img)):
                r -= 100
                print("crown - 2")

            if (env.enemy3(img)):
                r -= 5000
                done = 1
                print("crown - 3")


            # enemy tower reward calculate
            score1_now = env.checkET1(img)
            score2_now = env.checkET2(img)
            #print(f"score1 = {score1}, score1_now = {score1_now}")
            #print(f"score2 = {score2}, score2_now = {score2_now}")
            print(f"left tower HP = {score1}, right tower HP = {score2}")
            print(f"reward = {r}")
            if (score1_now < score1):
                r += 10 * (score1 - score1_now)
                score1 = score1_now

            if (score2_now < score2):
                r += 10 * (score2 - score2_now)
                score2 = score2_now


            #현재 이미지 캡처 후 변환
            img = pag.screenshot(region=(2605, 100, 510, 900))
            s_prime = env.return_state(img).cuda()
            #print(prob)
            model.put_data((s, a, r, s_prime, prob[0][a], done))

            s = s_prime
            

            if(r<-10000):
                print("too bad result")
                pag.click((2650, 850))
                #게임 X클릭
                time.sleep(0.5)
                img = pag.screenshot(region=(2605, 100, 510, 900))
                if(env.stop_game(img)):
                    pag.click((2930, 650))
                    model.clear_data()
                    break
            
            model.train_net()
            if done:
                break
            
        
        
        
        #print(f"how many time to train? = {train_time}")
            #opt.save_interval = 50
        
        save_interval = 500
        if(train_time % save_interval == 0):
            #print("Episode: {}. Total loss: {}, save_interval = {}".format(curr_episode, total_loss, curr_episode % save_interval))
            torch.save(model.state_dict(),"{}/clash_royale_PPO_v2_{}".format("trained_models", train_time))
        
        if done:
            
            writer.add_scalar("reward/epi", r, play_time)
            writer.flush()
            writer.add_scalar("clicks/epi", num_local_steps, play_time)
            writer.flush()
            writer.add_scalar("win_lose/epi", win_lose_flag, play_time)
            writer.flush()
            break
            
    print(f"how many time to choice = {num_local_steps}")        
    print("retry game")
    env.retryGame()
# Out:
# game start
# action = card 1
# click
# left tower HP = 100, right tower HP = 100
# reward = -1
# action = 2 3
# click
# left tower HP = 100, right tower HP = 100
# reward = 8
# action = 3 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 7
# action = 0 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 6
# action = 1 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 5
# action = 3 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 4
# action = 3 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 3
# action = 0 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 2
# action = 1 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 1
# action = 3 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 0
# action = 3 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -1
# action = 4 2
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -2
# action = rest action
# left tower HP = 100, right tower HP = 100
# reward = -3
# action = 2 2
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -4
# action = 3 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -5
# action = 3 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -6
# action = 0 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -7
# action = 2 0
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -8
# action = 0 0
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -9
# action = 0 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -10
# action = 2 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -11
# action = 3 0
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -12
# action = 0 0
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -13
# action = 2 3
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -14
# action = 2 3
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -15
# action = 3 3
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -16
# action = 3 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -17
# action = 2 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -18
# action = 0 2
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -19
# action = 0 5
# wrong click
# left tower HP = 94, right tower HP = 100
# reward = 40
# action = 0 3
# wrong click
# left tower HP = 88, right tower HP = 100
# reward = 99
# action = 1 1
# wrong click
# left tower HP = 88, right tower HP = 100
# reward = 98
# action = 2 3
# wrong click
# left tower HP = 84, right tower HP = 100
# reward = 137
# action = 2 0
# wrong click
# left tower HP = 84, right tower HP = 100
# reward = 136
# action = 4 4
# wrong click
# left tower HP = 76, right tower HP = 100
# reward = 215
# action = 2 1
# wrong click
# left tower HP = 76, right tower HP = 100
# reward = 214
# action = 1 2
# wrong click
# left tower HP = 68, right tower HP = 100
# reward = 293
# action = 0 2
# wrong click
# left tower HP = 68, right tower HP = 100
# reward = 292
# action = card 2
# click
# left tower HP = 64, right tower HP = 100
# reward = 331
# action = 0 5
# click
# crown - 1
# left tower HP = 64, right tower HP = 98
# reward = 260
# action = 0 1
# wrong click
# crown - 1
# left tower HP = 64, right tower HP = 98
# reward = 159
# action = 1 1
# wrong click
# crown - 1
# left tower HP = 64, right tower HP = 98
# reward = 58
# action = 4 5
# wrong click
# crown - 1
# left tower HP = 64, right tower HP = 98
# reward = -43
# action = 0 2
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -44
# action = 1 3
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -45
# action = 2 7
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -46
# action = 0 1
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -47
# action = 1 6
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -48
# action = 1 6
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -49
# action = 1 0
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -50
# action = 4 6
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -51
# action = 0 5
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -52
# action = 2 0
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -53
# action = 1 6
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -54
# action = 2 3
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -55
# action = 0 4
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -56
# action = 0 5
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -57
# action = 0 5
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -58
# action = 3 4
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -59
# action = card 3
# click
# left tower HP = 64, right tower HP = 98
# reward = -60
# action = 1 5
# click
# left tower HP = 64, right tower HP = 98
# reward = -51
# action = 2 6
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -52
# action = 1 5
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -53
# action = card 2
# click
# left tower HP = 64, right tower HP = 98
# reward = -54
# action = 1 3
# click
# left tower HP = 64, right tower HP = 98
# reward = -45
# action = 3 7
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -46
# action = 3 7
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -47
# action = 1 0
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -48
# action = 3 6
# wrong click
# left tower HP = 64, right tower HP = 98
# reward = -49
# action = 2 7
# wrong click
# crown - 3
# left tower HP = 64, right tower HP = 78
# reward = -4850
# how many time to choice = 70
# retry game
# game start
# action = 0 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -1
# action = 3 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -2
# action = card 3
# click
# left tower HP = 100, right tower HP = 100
# reward = -3
# action = card 2
# click
# left tower HP = 100, right tower HP = 100
# reward = -4
# action = 0 7
# click
# left tower HP = 100, right tower HP = 100
# reward = 5
# action = 3 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 4
# action = rest action
# left tower HP = 100, right tower HP = 100
# reward = 3
# action = 1 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 2
# action = 1 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 1
# action = 1 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = 0
# action = 3 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -1
# action = 4 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -2
# action = 0 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -3
# action = 0 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -4
# action = 2 0
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -5
# action = 4 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -6
# action = 0 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -7
# action = 0 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -8
# action = card 2
# click
# left tower HP = 100, right tower HP = 100
# reward = -9
# action = 3 2
# click
# left tower HP = 100, right tower HP = 100
# reward = 0
# action = card 1
# click
# left tower HP = 100, right tower HP = 100
# reward = -1
# action = 1 4
# click
# left tower HP = 100, right tower HP = 100
# reward = 8
# action = 0 1
# wrong click
# no Elixir
# left tower HP = 100, right tower HP = 100
# reward = -93
# action = 0 3
# wrong click
# no Elixir
# left tower HP = 100, right tower HP = 100
# reward = -194
# action = 4 1
# wrong click
# no Elixir
# left tower HP = 100, right tower HP = 100
# reward = -295
# action = card 1
# click
# no Elixir
# left tower HP = 100, right tower HP = 100
# reward = -396
# action = 2 7
# click
# left tower HP = 100, right tower HP = 100
# reward = -387
# action = card 2
# click
# left tower HP = 100, right tower HP = 100
# reward = -388
# action = 2 6
# click
# no Elixir
# left tower HP = 100, right tower HP = 100
# reward = -479
# action = 1 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -480
# 100 train is over
# action = 3 3
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -481
# action = 0 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -482
# action = 0 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -483
# action = 3 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -484
# action = 4 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -485
# action = 3 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -486
# action = 1 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -487
# action = card 4
# click
# left tower HP = 100, right tower HP = 100
# reward = -488
# action = 2 1
# click
# left tower HP = 100, right tower HP = 100
# reward = -479
# action = 0 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -480
# action = 4 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -481
# action = 2 5
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -482
# action = 2 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -483
# action = 1 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -484
# action = 2 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -485
# action = 4 0
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -486
# action = 3 7
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -487
# action = 1 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -488
# action = 4 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -489
# action = 4 6
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -490
# action = 4 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -491
# action = 2 5
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -492
# action = 2 3
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -493
# action = 2 1
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -494
# action = 1 4
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -495
# action = 2 2
# wrong click
# left tower HP = 100, right tower HP = 100
# reward = -496
# action = 1 2
# wrong click
# left tower HP = 92, right tower HP = 100
# reward = -417
# action = 4 2
# wrong click
# left tower HP = 88, right tower HP = 100
# reward = -378
# action = 3 1
# wrong click
# left tower HP = 78, right tower HP = 100
# reward = -279
# action = 1 7
# wrong click
# crown - 1
# left tower HP = 78, right tower HP = 100
# reward = -380
# action = 4 5
# wrong click
# crown - 1
# left tower HP = 54, right tower HP = 100
# reward = -241
# action = 0 0
# wrong click
# crown - 1
# left tower HP = 48, right tower HP = 100
# reward = -282
# action = 0 2
# wrong click
# crown - 1
# left tower HP = 40, right tower HP = 100
# reward = -303
# action = 0 1
# wrong click
# left tower HP = 32, right tower HP = 100
# reward = -224
# action = 4 5
# wrong click
# left tower HP = 28, right tower HP = 100
# reward = -185
# action = 1 3
# wrong click
# left tower HP = 6, right tower HP = 100
# reward = 34
# action = card 2
# click
# left tower HP = 6, right tower HP = 100
# reward = 33
# action = 0 3
# click
# left tower HP = 6, right tower HP = 98
# reward = 62
# action = 3 1
# wrong click
# no card
# left tower HP = 6, right tower HP = 98
# reward = 41
# action = 2 7
# wrong click
# no card
# left tower HP = 6, right tower HP = 98
# reward = 20
# action = card 3
# click
# left tower HP = 6, right tower HP = 98
# reward = 19
# action = 0 5
# click
# left tower HP = 6, right tower HP = 98
# reward = 28
# action = 0 0
# wrong click
# no card
# left tower HP = 6, right tower HP = 98
# reward = 7
# action = 0 5
# wrong click
# left tower HP = 6, right tower HP = 98
# reward = 6
# action = 2 0
# wrong click
# no card
# left tower HP = 6, right tower HP = 98
# reward = -15
# action = 0 5
# wrong click
# left tower HP = 6, right tower HP = 98
# reward = -16
# action = 0 7
# wrong click
# left tower HP = 6, right tower HP = 98
# reward = -17
# action = 3 7
# wrong click
# left tower HP = 6, right tower HP = 98
# reward = -18
# action = 2 3
# wrong click
# left tower HP = 6, right tower HP = 98
# reward = -19
# action = 2 1
# wrong click
# left tower HP = 6, right tower HP = 98
# reward = -20
# action = 3 1
# wrong click
# left tower HP = 6, right tower HP = 98
# reward = -21
# action = 2 0
# wrong click
# crown - 3
# left tower HP = 6, right tower HP = 98
# reward = -5022
# how many time to choice = 82
# retry game
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[241], line 220
#     218 print(f"how many time to choice = {num_local_steps}")
#     219 print("retry game")
# --> 220 env.retryGame()
#
# Cell In[231], line 195, in ENV.retryGame(self)
#     193 pag.click((2860, 875))
#     194 #print("step1 click")
# --> 195 time.sleep(5)
#     197 while(1):
#     198     img = pag.screenshot(region=(2605, 100, 510, 900))
#
# KeyboardInterrupt:

# %%
card_click_flag = 1pag.click((2650, 850))
#게임 X

# %%
pag.click((2900, 650))
#게임종료

# %%
img = pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/main0.png')
#clickEmpty1 = clickEmpty1.crop((2737, 573, 2987, 600))
#print(type(clickEmpty1))
plt.imshow(img)
#clickEmpty2 = np.array(img)
#cv2.imwrite('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/nocard.png', clickEmpty2)
#plt.imshow(clickEmpty1)

# %%
t1 = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/main0.png')
#plt.imshow(t1)
t2 = Image.fromarray(t1)
t3 = t2.crop((3050,165,3105,220))
t4 = np.array(t3)
cv2.imwrite('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/main_check.png', t4)
plt.imshow(t4)

# %%
img = pag.screenshot(region=(2605, 100, 510, 900))
plt.imshow(img)
env.checkMainPage(img)
if(env.checkMainPage(img)):
    print("As")
# Out:
# 0.9983697
# 0.9983697
# As

# %%
pag.click((2930, 650))

# %%
a = [[1, 2, 3, 4], [1, 2, 3, 4]]
print(a.size)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 2
#       1 a = [[1, 2, 3, 4], [1, 2, 3, 4]]
# ----> 2 print(a.size)
#
# AttributeError: 'list' object has no attribute 'size'
