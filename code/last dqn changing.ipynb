# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import collections
import random
import matplotlib.pyplot as plt
import pyautogui as pag
import PIL
import torchvision.transforms as transforms
import cv2
import numpy as np
from torch.utils.tensorboard import SummaryWriter
from PIL import Image
import time
import seaborn as sns


pag.FAILSAFE = False

# %%
#device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')
# device = torch.device('cuda:0')
writer = SummaryWriter()
train_time = 0

# DQN 모델 정의
class DQN(nn.Module):
    def __init__(self, num_actions):
        super(DQN, self).__init__()
        self.conv1 = nn.Sequential(nn.Conv2d(3, 16, 3, stride=2, padding=1),
                                   nn.BatchNorm2d(16),
                                   nn.ReLU(inplace=True))
        self.conv2 = nn.Sequential(nn.Conv2d(16, 32, 3, stride=2, padding=1),
                                   nn.BatchNorm2d(32),
                                   nn.ReLU(inplace=True))
        self.conv3 = nn.Sequential(nn.Conv2d(32, 64, 3, stride=2, padding=1),
                                   nn.BatchNorm2d(64),
                                   nn.ReLU(inplace=True))
        self.actor_linear = nn.Sequential(nn.Linear(462848, 256),
                                          nn.ReLU(inplace=True),
                                          nn.Linear(256, num_actions))
        #print(f"5 / {time.time()}")

    def forward(self, x):  # 각 action에 대한 가치를 softmax를 거쳐서 확률로 출력
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.actor_linear(x.reshape(x.size(0), -1))
        #x1 = x.to("cpu")
        #x1 = x1.detach().numpy()
        #x1 = np.insert(x1, 0, 0, axis=1)
        #x1 = np.insert(x1, 4, 0, axis=1)
        #x1 = np.append(x1, [[0,0,0]], axis=1)  # axis=0 행으로 값 추가
        #x1 = np.reshape(x1,(4,4))
        #plt.title("Weight heatmap", y = 1.05, size = 15)
        #sns.heatmap(x1, cmap="autumn", linewidths = 0.1, linecolor = "white",annot = True, annot_kws = {"size" : 16})
        #plt.show()
        return x
    
    def sample_action(self, obs, epsilon):
        out = self.forward(obs)
        coin = random.random()
        if coin < epsilon:
            return random.randint(0, 10)
        else:
            return out.argmax().item()

action_list = [[2720, 550], [2860, 550], [3000, 550], [2720 ,660], [2860, 660], [3000, 660], [2765, 900], [2855, 930], [2950, 900], [3055, 900], [-1, -1]]
#action list 정의. action list는 6개의 필드 위치와 4개의 카드 위치 그리고 한개의 아무것도 안하는 리워드를 주었다.
action_list_name = {0:'left top', 1:'center top', 2:'right top', 3:'right bottom', 4:'center bottom', 5:'center right', 6:'card 1', 7:'card 2', 8:'card 3', 9:'card 4', 10:'rest action'}


class ENV():
    def __init__(self):
        # screenshot의 위치 지정, 클래스 생성할때 가져오기

        # winflg와 lose flag 존재해야 함. 0으로 하는 건 grayscale
        self.winFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/weWin.png', 0)
        self.loseFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemyWin.png', 0)
        # nocard flag
        self.nocardFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/nocard.png')
        # noElixir flag
        self.noelixirFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/noElixir.png')
        self.startGameFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/battleStart.png')
        self.finishFlag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/battleFinish.png')
        self.enemy1Flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemy1.png')
        self.enemy2Flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemy2.png')
        self.enemy3Flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemy3.png')
    def return_state(self, img):
        # 스크린 샷을 인자로 받아와서 모델에 넣을 수 있도록 tensor로 변환
        tf = transforms.ToTensor()
        img_t = tf(img) # time.sleep(0.3)
        img_t = img_t.unsqueeze(0)
        # img_t = img_t.permute(1, 0, 2, 3)

        return img_t

    def check_finish(self,img):
    	finishMessage = cv2.cvtColor(self.finishFlag, cv2.COLOR_BGR2GRAY)
    	img = np.array(img)
    	img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    	ratio = cv2.matchTemplate(finishMessage, img, cv2.TM_CCOEFF_NORMED)
    	if (np.max(ratio) > 0.90):
    	    return 1
    	    
    	else:
    	    return 0
    	                
    def check_win(self, img):
        # 게임이 이겼는지 확인, screenshot을 가져와서 우리가 원하는 크기로 잘라서 확인
        # img = np.array(img)
        checkFlag1 = np.array(img.crop((225, 335, 280, 365)))
        checkFlag1 = cv2.cvtColor(checkFlag1, cv2.COLOR_BGR2GRAY)
        win_check = cv2.matchTemplate(checkFlag1, self.winFlag, cv2.TM_CCOEFF_NORMED)
        if win_check > 0.8:
            return 1

        else:
            return 0
           
    def check_lose(self, img):
        # 게임이 졌는지 확인, screenshot을 가져와서 우리가 원하는 크기로 잘라서 확인
        # img = np.array(img)
        checkFlag2 = np.array(img.crop((225, 85, 280, 115)))
        checkFlag2 = cv2.cvtColor(checkFlag2, cv2.COLOR_BGR2GRAY)
        lose_check = cv2.matchTemplate(checkFlag2, self.loseFlag, cv2.TM_CCOEFF_NORMED)
        if lose_check > 0.8:
            return 1

        else:
            return 0

    def check_card(self, img):
        # 카드를 선택하지 않았는지 확인, screenshot을 가져와서 init에 지정된 nocard 이미지와 비교하여 reward 부여
        nocard = cv2.cvtColor(self.nocardFlag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(nocard, img, cv2.TM_CCOEFF_NORMED)

        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0

    def check_elixir(self, img):
        noElixir = cv2.cvtColor(self.noelixirFlag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(noElixir, img, cv2.TM_CCOEFF_NORMED)

        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0

    def checkET1(self, img):
        score1 = 0
        checkFlag1 = np.array(img.crop((105, 135, 155, 136)))

        for i in range(50):
            if (checkFlag1[0][i][0] >= 96):
                score1 += 1

        score1 = score1 * 2
        return score1

    def checkET2(self, img):
        score2 = 0
        checkFlag2 = np.array(img.crop((371, 135, 421, 136)))

        for i in range(50):
            if (checkFlag2[0][i][0] >= 96):
                score2 += 1

        score2 = score2 * 2
        return score2

    def checkGameStart(self, img):
        startMessage = cv2.cvtColor(self.startGameFlag, cv2.COLOR_BGR2GRAY)
        img = np.array(img)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(startMessage, img, cv2.TM_CCOEFF_NORMED)
        if (np.max(ratio) > 0.90):
            # print(np.max(ratio))
            return 1

        else:
            return 0

    def enemy1(self, img):
        crownFlag1 = cv2.cvtColor(self.enemy1Flag, cv2.COLOR_BGR2GRAY)
        img1 = np.array(img)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(crownFlag1, img1, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            return 1
        else:
            return 0
        
    def enemy2(self, img):
        crownFlag2 = cv2.cvtColor(self.enemy2Flag, cv2.COLOR_BGR2GRAY)
        img1 = np.array(img)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(crownFlag2, img1, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            return 1
        else:
            return 0
        
    def enemy3(self, img):
        crownFlag3 = cv2.cvtColor(self.enemy3Flag, cv2.COLOR_BGR2GRAY)
        img1 = np.array(img)
        img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
        ratio = cv2.matchTemplate(crownFlag3, img1, cv2.TM_CCOEFF_NORMED)
        #print(np.max(ratio))
        if (np.max(ratio) > 0.90):
            return 1
        else:
            return 0

    # def checkOT1
    # def checkOT1
    # def checkOT1

    # 우리 타워와 상대 타워의 hp를 확인하여 reward 부여

    def retryGame(self):
        time.sleep(3)
        pag.click((2860, 875))
        time.sleep(5)
        pag.click((3070, 185))
        time.sleep(5)
        pag.click((2920, 385))
        time.sleep(3)
        pag.click((2950, 615))


class ReplayBuffer():
    def __init__(self):
        self.buffer = collections.deque()
        self.batch_size = 50
        self.size_limit = 1500

    def put(self, data):
        self.buffer.append(data)
        if len(self.buffer) > self.size_limit:
            self.buffer.popleft()

    def sample(self, n):
        print(f"self.buffer = {len(self.buffer)}")
        return random.sample(self.buffer, n)

    def size(self):
        return len(self.buffer)


def train(q, q_target, memory, gamma, optimizer, batch_size):
    global train_time
    for i in range(100):
        # print(f"batch_size = {batch_size}, memory.size = {memory.size()}")
        batch = memory.sample(batch_size)
        # print(f"size = {len(batch[0])}")
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []

        for transition in batch:
            
            s, a, r, s_prime, done_mask = transition
            s, s_prime, = s.cuda(), s_prime.cuda()  
            s_lst.append(s)
            a_lst.append([a])
            r_lst.append([r])
            s_prime_lst.append(s_prime)
            done_mask_lst.append([done_mask])      
           
            #s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = s_lst.cuda(), a_lst.cuda(), r_lst.cuda(), s_prime_lst.cuda(), done_mask_lst.cuda() 
        s_lst = torch.stack(s_lst).cuda()
        s_prime_lst = torch.stack(s_prime_lst).cuda()
        # print(f"about s = {type(s_lst)}")
        s, a, r, s_prime, done_mask = s_lst, torch.tensor(a_lst).cuda(), \
            torch.tensor(r_lst).cuda(), s_prime_lst, \
            torch.tensor(done_mask_lst).cuda()
                # print(f"about S = {type(s)}")
        s = s.squeeze()
        s_prime = s_prime.squeeze()
        q_out = q(s)
        
        q_a = q_out.gather(1, a)
        max_q_prime = q_target(s_prime).max(1)[0].unsqueeze(1)

        target = r + gamma * max_q_prime * done_mask
        loss = F.smooth_l1_loss(target, q_a)
        print(f"loss = {loss}")
        if train_time % 100 == 0:
            writer.add_scalar("Loss/train", loss, train_time)
            writer.flush()
        train_time += 1
        #writer.add_scalar("Loss/train", loss, train_time)
        #writer.flush()

        optimizer.zero_grad()
        #print("we got the end1")
        loss.backward()
        #print("we got the end2")
        optimizer.step()
        #print("we got the end3")
# Out:
# 2023-10-30 18:08:50.453302: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
env = ENV()
q = DQN(len(action_list))
q = q.cuda()
q_target = DQN(len(action_list))
q_target = q_target.cuda()
q_target.load_state_dict(q.state_dict())
memory = ReplayBuffer()

avg_t = 0
gamma = 0.98
batch_size = 50
optimizer = optim.Adam(q.parameters(), lr = 0.0005)

middleBuffer = []

n_epi = 0
done = 0

while (1):
    # s 변수 설정
    # region 에 left, top, width, height 형식으로 넘겨주면 된다.
    img = pag.screenshot(region=(2605, 100, 510, 900))
    img_t = env.return_state(img)
    s = img_t

    # reward 초기화
    reward = 0
    # enemy tower score / score1 = left, score2 = right
    score1 = 100
    score2 = 100
    t1 = time.time()
    start_flag = 0
    print("waiting for the battle to begin")

    while (1):
        while (start_flag == 0):
            # 스크린샷 찍기
            img = pag.screenshot(region=(2605, 100, 510, 900))

            if (env.checkGameStart(img)):
                # print("game start")
                time.sleep(2)
                pag.click((2860, 875))
                time.sleep(1)
                pag.click((2860, 875))
                start_flag = 1
                break
        # epsilon 조절
        epsilon = max(0.1, 0.5 - 0.01 * (train_time / 200))
        n_epi += 1
        print("==================================================")
        reward = 0
        # 스크린샷 찍기
        img = pag.screenshot(region=(2605, 100, 510, 900))
        print(f"episode = {n_epi}")
        # 모델에 넣기 위해 tensor로 변환
        img_t = env.return_state(img)
        img_t = img_t.cuda()
        s_prime = img_t
        a = q.sample_action(img_t, epsilon)
        
        

        if(a!=10):
            # 화면 클릭
            pag.click(action_list[a][0], action_list[a][1])
            
        # 승리 확인
        if (env.check_win(img)):
            print("win")
            reward += 500
            done = 1
        # 패배 확인
        if (env.check_lose(img)):
            print("lose")
            reward -= 500
            done = 1
        # no card확인
        if (env.check_card(img)):
            reward -= 1
            print("no card")

        # no elixir확인
        if (env.check_elixir(img)):
            reward -= 1
            print("no Elixir")
            
        if (env.enemy1(img)):
            reward -= 50
            print("crown - 1")
        
        if (env.enemy2(img)):
            reward -= 50
            print("crown - 2")
        
        if (env.enemy3(img)):
            reward -= 500
            done = 1
            print("crown - 3")


        # enemy tower reward calculate
        score1_now = env.checkET1(img)
        score2_now = env.checkET2(img)
        
        middleBuffer.append((s, a, reward, s_prime, done))
        #이부분 잘못된듯 -> epi 별 reward가 아니라 게임당 reward여야 될 듯
        
        #print(f"score1 = {score1}, score1_now = {score1_now}")
        #print(f"score2 = {score2}, score2_now = {score2_now}")
        print(f"left tower HP = {score1}, right tower HP = {score2}")
        if (score1_now < score1):
            reward += 16 * (score1 - score1_now)
            score1 = score1_now

        if (score2_now < score2):
            reward += 16 * (score2 - score2_now)
            score2 = score2_now
            
        #middleBuffer.append((s, a, reward, s_prime, done))
        #이부분 잘못된듯 -> epi 별 reward가 아니라 게임당 reward여야 될 듯
        
        print('action =', action_list_name[a], '    index = ', action_list[a][0], action_list[a][1])
        print("reward = ", reward)
        

        s = s_prime

        #속도조절
        time.sleep(0.3)

        if done == 1:
            break

    # memory size 2000넘으면 학습 시작
    if len(middleBuffer) >= 20:
        print(time.time() - t1)
        for i in range(len(middleBuffer)):
            memory.put(middleBuffer[i])

        print(len(memory.buffer))
        print("========================")
        # print(middleBuffer.size())
        middleBuffer = []

        train(q, q_target, memory, gamma, optimizer, batch_size)

        print(f"train time = {train_time}")
        q_target.load_state_dict(q.state_dict())
        print(f"epi = {n_epi}, buffer size = {memory.size()}, epsilon = {epsilon}")
        
    if train_time % 2000 == 0:
        # reak
        torch.save(q.state_dict(),"{}/clash_royale_DQN_{}".format("trained_models", train_time))
#         a = []
#         b = []
#         c = []
#         layer = 2
#         for i in range(q.conv1[0].weight.shape[0]):
#             q1 = q.conv1[0].weight[i][0]
#             q1 = q1.to("cpu")
#             q1 = q1.detach().numpy()
#             q1 = np.ravel(q1, order='C')
#             a.append(q1)
#             q2 = q.conv1[0].weight[i][1]
#             q2 = q2.to("cpu")
#             q2 = q2.detach().numpy()
#             q2 = np.ravel(q2, order='C') 
#             b.append(q2)
#             q3 = q.conv1[0].weight[i][2]
#             q3 = q3.to("cpu")
#             q3 = q3.detach().numpy()
#             q3 = np.ravel(q3, order='C')
#             c.append(q3)
#         a = np.ravel(a, order='C')
#         a = a.reshape(12, 12)   
#         sns.heatmap(a, cmap='hot')
#         plt.show()
#         b = np.ravel(b, order='C')
#         b = b.reshape(12, 12)   
#         sns.heatmap(b, cmap='hot')
#         plt.show()
#         c = np.ravel(c, order='C')
#         c = c.reshape(12, 12)   
#         sns.heatmap(c, cmap='hot')
#         plt.show()
    writer.add_scalar("reward/train", reward, train_time)
    writer.flush()
    env.retryGame()
    done = 0
    time.sleep(5)
# Out:
# waiting for the battle to begin
# ==================================================
# episode = 1
# left tower HP = 100, right tower HP = 100
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 2
# left tower HP = 100, right tower HP = 100
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 3
# no card
# left tower HP = 100, right tower HP = 100
# action = card 4     index =  3055 900
# reward =  -1
# ==================================================
# episode = 4
# left tower HP = 100, right tower HP = 100
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 5
# left tower HP = 100, right tower HP = 100
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 6
# left tower HP = 100, right tower HP = 100
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 7
# no card
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 8
# no card
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 9
# no card
# left tower HP = 100, right tower HP = 100
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 10
# crown - 1
# left tower HP = 100, right tower HP = 100
# action = center right     index =  3000 660
# reward =  -50
# ==================================================
# episode = 11
# crown - 1
# left tower HP = 100, right tower HP = 100
# action = card 2     index =  2855 930
# reward =  -50
# ==================================================
# episode = 12
# crown - 1
# left tower HP = 100, right tower HP = 100
# action = card 2     index =  2855 930
# reward =  -50
# ==================================================
# episode = 13
# left tower HP = 100, right tower HP = 100
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 14
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 15
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 16
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 17
# left tower HP = 100, right tower HP = 100
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 18
# left tower HP = 100, right tower HP = 100
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 19
# no card
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 20
# no card
# left tower HP = 100, right tower HP = 100
# action = card 4     index =  3055 900
# reward =  -1
# ==================================================
# episode = 21
# no card
# left tower HP = 100, right tower HP = 100
# action = left top     index =  2720 550
# reward =  -1
# ==================================================
# episode = 22
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 23
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 24
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 25
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = center right     index =  3000 660
# reward =  -1
# ==================================================
# episode = 26
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 27
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = center bottom     index =  2860 660
# reward =  -1
# ==================================================
# episode = 28
# left tower HP = 100, right tower HP = 100
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 29
# left tower HP = 100, right tower HP = 100
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 30
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 31
# no Elixir
# left tower HP = 100, right tower HP = 100
# action = right bottom     index =  2720 660
# reward =  31
# ==================================================
# episode = 32
# left tower HP = 100, right tower HP = 98
# action = card 4     index =  3055 900
# reward =  64
# ==================================================
# episode = 33
# no Elixir
# left tower HP = 100, right tower HP = 94
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 34
# no Elixir
# left tower HP = 100, right tower HP = 94
# action = center top     index =  2860 550
# reward =  127
# ==================================================
# episode = 35
# no Elixir
# left tower HP = 100, right tower HP = 86
# action = left top     index =  2720 550
# reward =  -1
# ==================================================
# episode = 36
# no Elixir
# left tower HP = 100, right tower HP = 86
# action = right bottom     index =  2720 660
# reward =  -1
# ==================================================
# episode = 37
# no Elixir
# left tower HP = 100, right tower HP = 86
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 38
# left tower HP = 100, right tower HP = 86
# action = rest action     index =  -1 -1
# reward =  192
# ==================================================
# episode = 39
# no Elixir
# left tower HP = 100, right tower HP = 74
# action = card 1     index =  2765 900
# reward =  127
# ==================================================
# episode = 40
# no card
# no Elixir
# left tower HP = 100, right tower HP = 66
# action = card 3     index =  2950 900
# reward =  222
# ==================================================
# episode = 41
# left tower HP = 100, right tower HP = 52
# action = center top     index =  2860 550
# reward =  160
# ==================================================
# episode = 42
# no Elixir
# left tower HP = 100, right tower HP = 42
# action = card 1     index =  2765 900
# reward =  127
# ==================================================
# episode = 43
# no Elixir
# left tower HP = 100, right tower HP = 34
# action = card 1     index =  2765 900
# reward =  31
# ==================================================
# episode = 44
# no Elixir
# left tower HP = 100, right tower HP = 32
# action = rest action     index =  -1 -1
# reward =  63
# ==================================================
# episode = 45
# left tower HP = 100, right tower HP = 28
# action = card 1     index =  2765 900
# reward =  64
# ==================================================
# episode = 46
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 47
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 48
# left tower HP = 100, right tower HP = 24
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 49
# no card
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 50
# no card
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 51
# no card
# left tower HP = 100, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  -1
# ==================================================
# episode = 52
# no card
# left tower HP = 100, right tower HP = 24
# action = center bottom     index =  2860 660
# reward =  -1
# ==================================================
# episode = 53
# left tower HP = 100, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 54
# left tower HP = 100, right tower HP = 24
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 55
# no card
# left tower HP = 100, right tower HP = 24
# action = rest action     index =  -1 -1
# reward =  -1
# ==================================================
# episode = 56
# no card
# left tower HP = 100, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 57
# no card
# left tower HP = 100, right tower HP = 24
# action = rest action     index =  -1 -1
# reward =  -1
# ==================================================
# episode = 58
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 59
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 60
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 61
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = rest action     index =  -1 -1
# reward =  -1
# ==================================================
# episode = 62
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 63
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = left top     index =  2720 550
# reward =  -1
# ==================================================
# episode = 64
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 65
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 66
# left tower HP = 100, right tower HP = 24
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 67
# no card
# left tower HP = 100, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  -1
# ==================================================
# episode = 68
# no card
# left tower HP = 100, right tower HP = 24
# action = center bottom     index =  2860 660
# reward =  -1
# ==================================================
# episode = 69
# left tower HP = 100, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 70
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = right top     index =  3000 550
# reward =  -1
# ==================================================
# episode = 71
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 72
# left tower HP = 100, right tower HP = 24
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 73
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = right bottom     index =  2720 660
# reward =  -1
# ==================================================
# episode = 74
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = right top     index =  3000 550
# reward =  -1
# ==================================================
# episode = 75
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 76
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 77
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 78
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = card 2     index =  2855 930
# reward =  -1
# ==================================================
# episode = 79
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center bottom     index =  2860 660
# reward =  -1
# ==================================================
# episode = 80
# left tower HP = 100, right tower HP = 24
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 81
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 82
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 83
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 84
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 85
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = card 2     index =  2855 930
# reward =  -1
# ==================================================
# episode = 86
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = right bottom     index =  2720 660
# reward =  -1
# ==================================================
# episode = 87
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = center right     index =  3000 660
# reward =  -1
# ==================================================
# episode = 88
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = rest action     index =  -1 -1
# reward =  -1
# ==================================================
# episode = 89
# left tower HP = 100, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 90
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 91
# left tower HP = 100, right tower HP = 24
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 92
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 93
# left tower HP = 100, right tower HP = 24
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 94
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 95
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 96
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 97
# left tower HP = 100, right tower HP = 24
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 98
# left tower HP = 100, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 99
# left tower HP = 100, right tower HP = 24
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 100
# left tower HP = 100, right tower HP = 24
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 101
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 102
# left tower HP = 100, right tower HP = 24
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 103
# left tower HP = 100, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 104
# left tower HP = 100, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 105
# left tower HP = 100, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 106
# left tower HP = 100, right tower HP = 24
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 107
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = rest action     index =  -1 -1
# reward =  -1
# ==================================================
# episode = 108
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  -1
# ==================================================
# episode = 109
# no Elixir
# left tower HP = 100, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  95
# ==================================================
# episode = 110
# left tower HP = 94, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  96
# ==================================================
# episode = 111
# left tower HP = 88, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  128
# ==================================================
# episode = 112
# left tower HP = 80, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  96
# ==================================================
# episode = 113
# left tower HP = 74, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  128
# ==================================================
# episode = 114
# left tower HP = 66, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 115
# left tower HP = 66, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 116
# left tower HP = 66, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 117
# left tower HP = 66, right tower HP = 24
# action = left top     index =  2720 550
# reward =  352
# ==================================================
# episode = 118
# left tower HP = 44, right tower HP = 24
# action = left top     index =  2720 550
# reward =  192
# ==================================================
# episode = 119
# no card
# left tower HP = 32, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  127
# ==================================================
# episode = 120
# no card
# left tower HP = 24, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  159
# ==================================================
# episode = 121
# no card
# left tower HP = 14, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 122
# no card
# left tower HP = 14, right tower HP = 24
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 123
# left tower HP = 14, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  96
# ==================================================
# episode = 124
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 125
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 126
# left tower HP = 8, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 127
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 128
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 129
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 130
# left tower HP = 8, right tower HP = 24
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 131
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 132
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 133
# left tower HP = 8, right tower HP = 24
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 134
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 135
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 136
# left tower HP = 8, right tower HP = 24
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 137
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 138
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 139
# left tower HP = 8, right tower HP = 24
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 140
# left tower HP = 8, right tower HP = 24
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 141
# no Elixir
# left tower HP = 8, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 142
# no Elixir
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 143
# no Elixir
# left tower HP = 8, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 144
# left tower HP = 8, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 145
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 146
# left tower HP = 8, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 147
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 148
# left tower HP = 8, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 149
# left tower HP = 8, right tower HP = 24
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 150
# left tower HP = 8, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 151
# left tower HP = 8, right tower HP = 24
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 152
# left tower HP = 8, right tower HP = 24
# action = card 3     index =  2950 900
# reward =  256
# ==================================================
# episode = 153
# left tower HP = 8, right tower HP = 8
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 154
# left tower HP = 8, right tower HP = 8
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 155
# left tower HP = 8, right tower HP = 8
# action = right bottom     index =  2720 660
# reward =  96
# ==================================================
# episode = 156
# left tower HP = 2, right tower HP = 8
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 157
# left tower HP = 2, right tower HP = 8
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 158
# left tower HP = 2, right tower HP = 8
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 159
# left tower HP = 2, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 160
# left tower HP = 2, right tower HP = 8
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 161
# left tower HP = 2, right tower HP = 8
# action = right top     index =  3000 550
# reward =  32
# ==================================================
# episode = 162
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 163
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 164
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 165
# left tower HP = 0, right tower HP = 8
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 166
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 167
# left tower HP = 0, right tower HP = 8
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 168
# crown - 2
# left tower HP = 0, right tower HP = 8
# action = center right     index =  3000 660
# reward =  -50
# ==================================================
# episode = 169
# no card
# crown - 2
# left tower HP = 0, right tower HP = 8
# action = center bottom     index =  2860 660
# reward =  -51
# ==================================================
# episode = 170
# crown - 2
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  -50
# ==================================================
# episode = 171
# no card
# left tower HP = 0, right tower HP = 8
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 172
# no card
# left tower HP = 0, right tower HP = 8
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 173
# left tower HP = 0, right tower HP = 8
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 174
# no card
# left tower HP = 0, right tower HP = 8
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 175
# left tower HP = 0, right tower HP = 8
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 176
# no card
# left tower HP = 0, right tower HP = 8
# action = center right     index =  3000 660
# reward =  -1
# ==================================================
# episode = 177
# no card
# left tower HP = 0, right tower HP = 8
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 178
# left tower HP = 0, right tower HP = 8
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 179
# no card
# left tower HP = 0, right tower HP = 8
# action = center top     index =  2860 550
# reward =  -1
# ==================================================
# episode = 180
# no card
# left tower HP = 0, right tower HP = 8
# action = center bottom     index =  2860 660
# reward =  -1
# ==================================================
# episode = 181
# no card
# left tower HP = 0, right tower HP = 8
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 182
# no card
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  -1
# ==================================================
# episode = 183
# no card
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  -1
# ==================================================
# episode = 184
# left tower HP = 0, right tower HP = 8
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 185
# left tower HP = 0, right tower HP = 8
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 186
# left tower HP = 0, right tower HP = 8
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 187
# left tower HP = 0, right tower HP = 8
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 188
# left tower HP = 0, right tower HP = 8
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 189
# no Elixir
# left tower HP = 0, right tower HP = 8
# action = center right     index =  3000 660
# reward =  -1
# ==================================================
# episode = 190
# no Elixir
# left tower HP = 0, right tower HP = 8
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 191
# no Elixir
# left tower HP = 0, right tower HP = 8
# action = card 2     index =  2855 930
# reward =  -1
# ==================================================
# episode = 192
# left tower HP = 0, right tower HP = 8
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 193
# left tower HP = 0, right tower HP = 8
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 194
# no card
# left tower HP = 0, right tower HP = 8
# action = card 1     index =  2765 900
# reward =  -1
# ==================================================
# episode = 195
# no card
# left tower HP = 0, right tower HP = 8
# action = right top     index =  3000 550
# reward =  -1
# ==================================================
# episode = 196
# left tower HP = 0, right tower HP = 8
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 197
# left tower HP = 0, right tower HP = 8
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 198
# no card
# left tower HP = 0, right tower HP = 8
# action = card 3     index =  2950 900
# reward =  -1
# ==================================================
# episode = 199
# no card
# left tower HP = 0, right tower HP = 8
# action = card 2     index =  2855 930
# reward =  127
# ==================================================
# episode = 200
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 201
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 202
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 203
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 204
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 205
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 206
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 207
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 208
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 209
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 210
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 211
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 212
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 213
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 214
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 215
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 216
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 217
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 218
# left tower HP = 0, right tower HP = 0
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 219
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 220
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 221
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 222
# left tower HP = 0, right tower HP = 0
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 223
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 224
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 225
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 226
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 227
# left tower HP = 0, right tower HP = 0
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 228
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 229
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 230
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 231
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 232
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 233
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 234
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 235
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 236
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 237
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 238
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 239
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 240
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 241
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 242
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 243
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 244
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 245
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 246
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 247
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 248
# left tower HP = 0, right tower HP = 0
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 249
# left tower HP = 0, right tower HP = 0
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 250
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 251
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 252
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 253
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 254
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 255
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 256
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 257
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 258
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 259
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 260
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 261
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 262
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 263
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 264
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 265
# left tower HP = 0, right tower HP = 0
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 266
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 267
# left tower HP = 0, right tower HP = 0
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 268
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 269
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 270
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 271
# left tower HP = 0, right tower HP = 0
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 272
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 273
# left tower HP = 0, right tower HP = 0
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 274
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 275
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 276
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 277
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 278
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 279
# left tower HP = 0, right tower HP = 0
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 280
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 281
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 282
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 283
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 284
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 285
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 286
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 287
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 288
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 289
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 290
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 291
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 292
# left tower HP = 0, right tower HP = 0
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 293
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 294
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 295
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 296
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 297
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 298
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 299
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 300
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 301
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 302
# left tower HP = 0, right tower HP = 0
# ...
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 1717
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1718
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1719
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1720
# left tower HP = 0, right tower HP = 0
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 1721
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1722
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1723
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1724
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1725
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 1726
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 1727
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1728
# left tower HP = 0, right tower HP = 0
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 1729
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1730
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1731
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1732
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1733
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1734
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1735
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1736
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 1737
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1738
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1739
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1740
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1741
# left tower HP = 0, right tower HP = 0
# action = left top     index =  2720 550
# reward =  0
# ==================================================
# episode = 1742
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1743
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1744
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1745
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1746
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1747
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1748
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1749
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1750
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1751
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1752
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1753
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1754
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 1755
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 1756
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 1757
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1758
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 1759
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1760
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1761
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 1762
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1763
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1764
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1765
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 1766
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1767
# left tower HP = 0, right tower HP = 0
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 1768
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1769
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 1770
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1771
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1772
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1773
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1774
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1775
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1776
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1777
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1778
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 1779
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 1780
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1781
# left tower HP = 0, right tower HP = 0
# action = rest action     index =  -1 -1
# reward =  0
# ==================================================
# episode = 1782
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1783
# left tower HP = 0, right tower HP = 0
# action = card 1     index =  2765 900
# reward =  0
# ==================================================
# episode = 1784
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1785
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1786
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1787
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 1788
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1789
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1790
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1791
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1792
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1793
# left tower HP = 0, right tower HP = 0
# action = center bottom     index =  2860 660
# reward =  0
# ==================================================
# episode = 1794
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 1795
# left tower HP = 0, right tower HP = 0
# action = card 2     index =  2855 930
# reward =  0
# ==================================================
# episode = 1796
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1797
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1798
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1799
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 1800
# left tower HP = 0, right tower HP = 0
# action = card 4     index =  3055 900
# reward =  0
# ==================================================
# episode = 1801
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1802
# left tower HP = 0, right tower HP = 0
# action = center top     index =  2860 550
# reward =  0
# ==================================================
# episode = 1803
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1804
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1805
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1806
# left tower HP = 0, right tower HP = 0
# action = center right     index =  3000 660
# reward =  0
# ==================================================
# episode = 1807
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1808
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1809
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1810
# left tower HP = 0, right tower HP = 0
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 1811
# left tower HP = 0, right tower HP = 0
# action = card 3     index =  2950 900
# reward =  0
# ==================================================
# episode = 1812
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1813
# left tower HP = 0, right tower HP = 0
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 1814
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1815
# left tower HP = 0, right tower HP = 0
# action = right bottom     index =  2720 660
# reward =  0
# ==================================================
# episode = 1816
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1817
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# episode = 1818
# left tower HP = 0, right tower HP = 0
# action = right top     index =  3000 550
# reward =  0
# ==================================================
# KeyboardInterrupt

# %%
img = pag.screenshot(region=(2605, 100, 510, 900))
plt.imshow(img)

# %%
crownFlag1= np.array(img.crop((160, 215, 350, 300)))
plt.imshow(checkFlag2)

# %%
#img = pag.screenshot(region=(2605, 100, 510, 900))
#print(env.check_lose(img))
checkFlag2 = np.array(img.crop((160, 215, 350, 300)))
plt.imshow(checkFlag2)
cv2.imwrite('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemy2.png', checkFlag2)

# %%
checkFlag2 = np.array(img.crop((225, 85, 280, 115)))

# %%
print(q.conv1[0].in_channels)
print(q.conv1[0].out_channels)
        #x1 = x.to("cpu")
        #x1 = x1.detach().numpy()
        #x1 = np.insert(x1, 0, 0, axis=1)
        #x1 = np.insert(x1, 4, 0, axis=1)
        #x1 = np.append(x1, [[0,0,0]], axis=1)  # axis=0 행으로 값 추가
        #x1 = np.reshape(x1,(4,4))
        #plt.title("Weight heatmap", y = 1.05, size = 15)
        #sns.heatmap(x1, cmap="autumn", linewidths = 0.1, linecolor = "white",annot = True, annot_kws = {"size" : 16})
        #plt.show()

# %%
q.conv1[0].weight[0]
# Out:
# tensor([[[-0.1910,  0.0657,  0.1492],
#          [-0.1569, -0.1872, -0.0375],
#          [ 0.0141, -0.0596, -0.0620]],
#
#         [[ 0.1852, -0.1182, -0.1788],
#          [-0.0704,  0.0579, -0.1374],
#          [-0.0600, -0.1272, -0.0678]],
#
#         [[-0.1710, -0.0985,  0.0243],
#          [ 0.0894, -0.0798,  0.1439],
#          [-0.0811,  0.0274, -0.0341]]], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
q1 = q.conv1[0].weight[0][0]
q1 = q1.to("cpu")
q1=q1.detach().numpy()

# %%
np.ravel(q1, order='C')
# Out:
# array([-0.19103229,  0.06570474,  0.14923981, -0.15693238, -0.18720873,
#        -0.03745046,  0.01411462, -0.0595714 , -0.06198703], dtype=float32)

# %%
q.conv1[0].weight[1][0]
# Out:
# tensor([[-0.0305, -0.1291,  0.1786],
#         [-0.0957, -0.0133, -0.0801],
#         [-0.0670,  0.1225, -0.0574]], device='cuda:0',
#        grad_fn=<SelectBackward0>)

# %%
a = []
b=[]
c=[]
layer = 2
for i in range(q.conv1[0].weight.shape[0]):
    q1 = q.conv1[0].weight[i][0]
    q1 = q1.to("cpu")
    q1 = q1.detach().numpy()
    q1 = np.ravel(q1, order='C')
    a.append(q1)
    q2 = q.conv1[0].weight[i][1]
    q2 = q2.to("cpu")
    q2 = q2.detach().numpy()
    q2 = np.ravel(q2, order='C') #ㅎㅇㅎㅇㅎㅇㅎㅇㅎㅇㅎㅇ3안녕? 너 일단 할거해
    b.append(q2)
    q3 = q.conv1[0].weight[i][2]
    q3 = q3.to("cpu")
    q3 = q3.detach().numpy()
    q3 = np.ravel(q3, order='C')
    c.append(q3)
a = np.ravel(a, order='C')
a = a.reshape(12, 12)   
sns.heatmap(a, cmap='hot')
plt.show()
b = np.ravel(b, order='C')
b = b.reshape(12, 12)   
sns.heatmap(b, cmap='hot')
plt.show()
c = np.ravel(c, order='C')
c = c.reshape(12, 12)   
sns.heatmap(c, cmap='hot')
plt.show()

# %%
sns.heatmap(a, cmap='hot')
plt.show()

# %%
q.conv1[0]
# Out:
# Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))

# %%
q.conv1[0].weight
# Out:
# Parameter containing:
# tensor([[[[-0.1763,  0.1101, -0.1895],
#           [-0.0492,  0.0585, -0.0273],
#           [ 0.0278,  0.0520,  0.0017]],
#
#          [[ 0.0356, -0.1228, -0.0450],
#           [ 0.0269,  0.1062,  0.0014],
#           [-0.0567, -0.1588,  0.1233]],
#
#          [[ 0.0646,  0.1213,  0.1769],
#           [ 0.0969,  0.1143, -0.0974],
#           [-0.0146,  0.1350,  0.0694]]],
#
#
#         [[[-0.0149, -0.1712, -0.0329],
#           [-0.0655,  0.0070, -0.1664],
#           [ 0.0603,  0.1577,  0.1888]],
#
#          [[ 0.0605,  0.1317, -0.0412],
#           [-0.1615,  0.0245, -0.0953],
#           [ 0.1340, -0.0809, -0.0134]],
#
#          [[-0.1591,  0.0205,  0.0272],
#           [ 0.0890, -0.1222,  0.1412],
#           [ 0.1244,  0.0753, -0.0512]]],
#
#
#         [[[-0.1570, -0.0613,  0.1749],
#           [-0.1081, -0.1779, -0.1305],
#           [ 0.1085,  0.0962, -0.1438]],
#
#          [[-0.1118, -0.1327, -0.0184],
#           [-0.1789, -0.0698, -0.0759],
#           [-0.0646,  0.0879, -0.1843]],
#
#          [[ 0.0686, -0.0376, -0.0047],
#           [ 0.0168, -0.1180,  0.1559],
#           [ 0.0773,  0.0995,  0.1034]]],
#
#
#         [[[ 0.0331,  0.0105, -0.0035],
#           [-0.1564,  0.1296,  0.0959],
#           [-0.0542,  0.0525,  0.1100]],
#
#          [[-0.1321,  0.0029, -0.1539],
#           [ 0.1304, -0.1264, -0.1068],
#           [ 0.0211,  0.1435, -0.1503]],
#
#          [[-0.1862, -0.0620,  0.0563],
#           [ 0.0291, -0.1030,  0.0841],
#           [ 0.0675,  0.0719, -0.1241]]],
#
#
#         [[[-0.0100,  0.1163,  0.1323],
#           [ 0.1418,  0.1541, -0.0785],
#           [-0.0468, -0.0227,  0.0123]],
#
#          [[ 0.0035, -0.1669, -0.0638],
#           [-0.1484,  0.0669, -0.0851],
#           [-0.0759, -0.0095,  0.1072]],
#
#          [[-0.0520, -0.0703, -0.0900],
#           [ 0.0999, -0.1550,  0.0552],
#           [-0.0514,  0.1915,  0.0267]]],
#
#
#         [[[-0.1469, -0.0387,  0.0116],
#           [ 0.0151,  0.1164,  0.0054],
#           [ 0.0649, -0.0275, -0.1668]],
#
#          [[ 0.1092, -0.0894, -0.1527],
#           [-0.0243, -0.0040,  0.1084],
#           [-0.0817, -0.1255,  0.0724]],
#
#          [[-0.0924, -0.1156, -0.1185],
#           [ 0.1133, -0.1773,  0.0516],
#           [-0.0793,  0.0218, -0.0359]]],
#
#
#         [[[ 0.0917, -0.0855,  0.1792],
#           [ 0.1667,  0.0269,  0.1315],
#           [-0.0106, -0.0866,  0.0825]],
#
#          [[-0.0753,  0.1827, -0.0297],
#           [-0.0835, -0.0919, -0.0172],
#           [ 0.0580,  0.0429,  0.1491]],
#
#          [[ 0.1672,  0.0342, -0.1245],
#           [-0.1176, -0.0218,  0.1479],
#           [ 0.0596, -0.0806, -0.1350]]],
#
#
#         [[[ 0.1783,  0.1121,  0.1577],
#           [ 0.0027,  0.1543, -0.0870],
#           [ 0.0683,  0.1755, -0.0224]],
#
#          [[-0.1205, -0.0273, -0.0706],
#           [ 0.0895,  0.0121, -0.1876],
#           [-0.1582,  0.0765,  0.0261]],
#
#          [[ 0.0517, -0.0434,  0.1339],
#           [-0.0130,  0.1021, -0.0746],
#           [ 0.1578,  0.1038, -0.0417]]],
#
#
#         [[[-0.0380, -0.1456, -0.0545],
#           [ 0.1607, -0.0444, -0.0815],
#           [-0.1395,  0.0358,  0.1037]],
#
#          [[-0.1668, -0.1634, -0.0404],
#           [-0.1598,  0.0649,  0.1441],
#           [-0.1167,  0.1630,  0.1840]],
#
#          [[ 0.0869, -0.0017, -0.0793],
#           [-0.0841,  0.1118, -0.1456],
#           [-0.0486,  0.1364, -0.0820]]],
#
#
#         [[[ 0.1893,  0.1509,  0.0513],
#           [-0.1108, -0.0034,  0.1593],
#           [ 0.0948, -0.1094, -0.1205]],
#
#          [[ 0.0651,  0.0388,  0.0410],
#           [ 0.0150, -0.0027,  0.1886],
#           [ 0.0524,  0.0359,  0.1339]],
#
#          [[ 0.0531,  0.1082,  0.1780],
#           [-0.0172,  0.1026, -0.1572],
#           [-0.1248,  0.0421, -0.1131]]],
#
#
#         [[[-0.1757,  0.1292,  0.1386],
#           [-0.1789,  0.0010,  0.0778],
#           [ 0.1662,  0.1446,  0.0492]],
#
#          [[ 0.1331,  0.1206,  0.0019],
#           [-0.1274,  0.0174, -0.0115],
#           [ 0.0617, -0.1666, -0.1565]],
#
#          [[-0.1105, -0.0011,  0.1141],
#           [ 0.0908,  0.1545, -0.0628],
#           [-0.1237,  0.1367, -0.1743]]],
#
#
#         [[[ 0.0229, -0.0384, -0.0246],
#           [ 0.1862, -0.1096, -0.0161],
#           [-0.0031, -0.1438, -0.0944]],
#
#          [[-0.0821, -0.0822, -0.1106],
#           [-0.1913, -0.0144, -0.0564],
#           [-0.0809, -0.0236,  0.1367]],
#
#          [[-0.1148,  0.1434, -0.1644],
#           [-0.1415,  0.0218, -0.0171],
#           [-0.1507,  0.0821, -0.1396]]],
#
#
#         [[[-0.1279,  0.0201, -0.1352],
#           [ 0.1627, -0.1319, -0.0448],
#           [-0.1688,  0.0047, -0.0186]],
#
#          [[-0.1465, -0.0444,  0.0964],
#           [-0.0191, -0.1658, -0.0311],
#           [ 0.1446, -0.0948, -0.0950]],
#
#          [[-0.0057,  0.0619, -0.1390],
#           [-0.1133,  0.1719, -0.1109],
#           [ 0.1368, -0.0293, -0.1440]]],
#
#
#         [[[ 0.1499,  0.1107, -0.0481],
#           [-0.1499,  0.0757, -0.0460],
#           [ 0.1863,  0.1862,  0.1245]],
#
#          [[-0.0894, -0.0937, -0.0472],
#           [ 0.1832, -0.1372, -0.1557],
#           [ 0.0363, -0.1345, -0.1182]],
#
#          [[ 0.0098,  0.0075,  0.1370],
#           [ 0.1805,  0.1841, -0.1046],
#           [-0.1552, -0.0143,  0.0089]]],
#
#
#         [[[-0.0289,  0.0117,  0.0013],
#           [ 0.0804,  0.0524,  0.0797],
#           [-0.1114, -0.1744,  0.0563]],
#
#          [[ 0.0861,  0.0179,  0.1511],
#           [-0.1741,  0.0502,  0.1905],
#           [-0.1121,  0.1073,  0.1384]],
#
#          [[-0.0614,  0.1782,  0.0580],
#           [ 0.0791,  0.1758,  0.0332],
#           [-0.1697,  0.0950,  0.1780]]],
#
#
#         [[[-0.0093,  0.0833,  0.1231],
#           [ 0.0915, -0.1762,  0.1324],
#           [ 0.0772,  0.1539, -0.1288]],
#
#          [[-0.0730,  0.0999,  0.1215],
#           [ 0.0764, -0.1454, -0.1297],
#           [-0.1105,  0.1202, -0.1881]],
#
#          [[ 0.0047,  0.1024, -0.1775],
#           [ 0.0675, -0.0275,  0.1657],
#           [ 0.0191, -0.1479, -0.0034]]]], device='cuda:0', requires_grad=True)
