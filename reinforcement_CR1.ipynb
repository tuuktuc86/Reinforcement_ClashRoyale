# %%
import pyautogui as pag
import time

for i in range(10):
    print(pag.position())
    pag.sleep(0.5)
#75에 30 # 1920, 1080

#cr 환경 725, 120 1220, 1000

# 3115, 1000

# 2720, 550
# 2860, 550

#2685 900 
#2725 940

# 3000, 550
# 2720 ,660
# 2860, 660
# 3000, 660
# Out:
# Point(x=927, y=433)
# Point(x=927, y=433)
# Point(x=920, y=431)
# Point(x=896, y=462)
# Point(x=587, y=627)
# Point(x=587, y=627)
# Point(x=582, y=623)
# Point(x=582, y=623)
# Point(x=657, y=586)
# Point(x=691, y=576)

# %%
list_box = []

# %%
for i in range(5):
    for j in range(8):
        list_box.append((2655+j*58.571, 510+i*63.75))
        
list_box
# Out:
# [(2655.0, 510.0),
#  (2713.571, 510.0),
#  (2772.142, 510.0),
#  (2830.713, 510.0),
#  (2889.284, 510.0),
#  (2947.855, 510.0),
#  (3006.426, 510.0),
#  (3064.997, 510.0),
#  (2655.0, 573.75),
#  (2713.571, 573.75),
#  (2772.142, 573.75),
#  (2830.713, 573.75),
#  (2889.284, 573.75),
#  (2947.855, 573.75),
#  (3006.426, 573.75),
#  (3064.997, 573.75),
#  (2655.0, 637.5),
#  (2713.571, 637.5),
#  (2772.142, 637.5),
#  (2830.713, 637.5),
#  (2889.284, 637.5),
#  (2947.855, 637.5),
#  (3006.426, 637.5),
#  (3064.997, 637.5),
#  (2655.0, 701.25),
#  (2713.571, 701.25),
#  (2772.142, 701.25),
#  (2830.713, 701.25),
#  (2889.284, 701.25),
#  (2947.855, 701.25),
#  (3006.426, 701.25),
#  (3064.997, 701.25),
#  (2655.0, 765.0),
#  (2713.571, 765.0),
#  (2772.142, 765.0),
#  (2830.713, 765.0),
#  (2889.284, 765.0),
#  (2947.855, 765.0),
#  (3006.426, 765.0),
#  (3064.997, 765.0)]

# %%
for click in list_box:
    pag.moveTo(click[0], click[1])
    pag.sleep(0.5)

# %%
for i in range(1):
    img = pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/screenshot1.png',region=(2605, 100, 510, 900))
    
    #plt.imshow((np.array(pag.screenshot(region=(2730, 385, 260, 30)))))

# %%
from pynput.mouse import Listener

coord = []

def click(x, y, button, pressed):
    if pressed:
        x = int(x)
        y = int(x)
        coord.append(x)
        coord.append(y)
        print(coord)
        
with Listener(on_click = click) as Listener:
    Listener.join()
# Out:
# [438, 438]
# [438, 438, 405, 405]
# [438, 438, 405, 405, 1713, 1713]
# [438, 438, 405, 405, 1713, 1713, 1713, 1713]
# [438, 438, 405, 405, 1713, 1713, 1713, 1713, 1761, 1761]
# [438, 438, 405, 405, 1713, 1713, 1713, 1713, 1761, 1761, 1664, 1664]
# [438, 438, 405, 405, 1713, 1713, 1713, 1713, 1761, 1761, 1664, 1664, 812, 812]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[127], line 14
#      11         print(coord)
#      13 with Listener(on_click = click) as Listener:
# ---> 14     Listener.join()
#
# File ~/anaconda3/envs/torch_book/lib/python3.9/site-packages/pynput/_util/__init__.py:269, in AbstractListener.join(self, *args)
#     268 def join(self, *args):
# --> 269     super(AbstractListener, self).join(*args)
#     271     # Reraise any exceptions
#     272     try:
#
# ...

# %%
clickEmpty = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/screenshot.png')
clickEmpty1=Image.fromarray(clickEmpty)

clickEmpty1 = clickEmpty1.crop((2737, 573, 2987, 600))
print(type(clickEmpty1))
clickEmpty2 = np.array(clickEmpty1)
cv2.imwrite('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/nocard.png', clickEmpty2)
plt.imshow(clickEmpty1)
# Out:
# <class 'PIL.Image.Image'>

# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# %%
noElixir = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/screenshot_022.png')
noElixir1 = Image.fromarray(noElixir)
noElixir2 = noElixir1.crop((2770,530,2995,560))

noElixir2 = np.array(noElixir2)
cv2.imwrite('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/noElixir.png', noElixir2)
plt.imshow(noElixir2)

# %%
t1 = time.time()
sampleTest = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/screenshot.png')
nocard = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/nocard.png')
print(type(nocard))
checkRate = cv2.matchTemplate(sampleTest,nocard,cv2.TM_CCOEFF_NORMED)
print(np.max(checkRate))
t2 = time.time()

print(t2 - t1)
# Out:
# <class 'numpy.ndarray'>
# 0.9999999
# 0.23882818222045898

# %%
img = pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemyWin.png',region=(2830, 185, 55, 30))
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
t1 = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemyWin_000.png')
#plt.imshow(t1)
t2 = Image.fromarray(t1)
t3 = t2.crop((2830,185,2830+55,185+30))
t4 = np.array(t3)
cv2.imwrite('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemyWin.png', t4)
plt.imshow(t4)

# %%
import time
thistime = time.time()
img = pag.screenshot(region = (2605, 100, 510, 900))
#img = np.array(img)
checkFlag1 = img.crop((225,85,280,115))
checkFlag2 = img.crop((225,85,280,115))
nexttime = time.time()
print(nexttime - thistime)
# Out:
# 0.24247074127197266

# %%
from PIL import Image

# %%
win_flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/weWin.png', 0)
#win_flag = Image.fromarray(win_flag)
lose_flag = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemyWin.png', 0)
#lose_flag = Image.fromarray(lose_flag)

img = pag.screenshot(region = (2605, 100, 510, 900))

img = np.array(img)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#pil_image=Image.fromarray(np_array)
win_check=cv2.matchTemplate(img,win_flag,cv2.TM_CCOEFF_NORMED)
print(np.max(win_check))
# Out:
# 0.92212105

# %%
plt.imshow(win_flag)

# %%
print(np.shape(win_flag))
print(np.shape(lose_flag))
# Out:
# (30, 55, 3)
# (30, 55, 3)

# %%
#thistime = time.time()
timelist = []
for i in range(50000):
    t1 = time.time()
    img = pag.screenshot(region = (2605, 100, 510, 900))
    
    checkFlag1 = np.array(img.crop((225,335,280,365)))
    checkFlag1 = cv2.cvtColor(checkFlag1, cv2.COLOR_BGR2GRAY)
    checkFlag2 = np.array(img.crop((225,85,280,115)))
    checkFlag2 = cv2.cvtColor(checkFlag2, cv2.COLOR_BGR2GRAY)
    
    win_check=cv2.matchTemplate(checkFlag1,win_flag,cv2.TM_CCOEFF_NORMED)
    lose_check = cv2.matchTemplate(checkFlag2,lose_flag,cv2.TM_CCOEFF_NORMED)
    if win_check > 0.8:
        print(win_check, lose_check)
        print('win')
        break
    elif lose_check > 0.8:
        print(win_check, lose_check)
        print('lose')
        break
        
    t2 = time.time()
    timelist.append(t2-t1)
    
print(timelist)
#endtime = time.time()
# Out:
# [[0.99411607]] [[0.0077733]]
# win
# ...

# %%
img = pag.screenshot(region = (2605, 100, 510, 900))

checkFlag1 = np.array(img.crop((225,85,280,115)))
checkFlag2 = np.array(img.crop((225,85,280,115)))
    
win_check=cv2.matchTemplate(win_flag,checkFlag1,cv2.TM_CCOEFF_NORMED)
#lose_check = cv2.matchTemplate(screenshot,lose,cv2.TM_CCOEFF_NORMED)
print(win_check, lose_check)

if lose_check > 0.5:
    print("lose")
# Out:
# [[0.7422103]] [[0.95864683]]
# lose

# %%
checkFlag1 = np.array(img.crop((225,85,280,115)))
win_check=cv2.matchTemplate(screenshot,lose,cv2.TM_CCOEFF_NORMED)

# %%
plt.imshow(checkFlag1)

# %%
for i in range(1000):
    pag.screenshot()

# %%
img = pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/weWin.png',region=(2830, 435, 55, 30))
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
t1 = time.time()
img = pag.screenshot(region = (2605, 100, 510, 900))

checkFlag1 = np.array(img.crop((225,335,280,365)))
checkFlag1 = cv2.cvtColor(checkFlag1, cv2.COLOR_BGR2GRAY)
checkFlag2 = np.array(img.crop((225,85,280,115)))
plt.imshow(win_flag)
win_check=cv2.matchTemplate(checkFlag1,win_flag,cv2.TM_CCOEFF_NORMED)
lose_check = cv2.matchTemplate(checkFlag2,lose_flag,cv2.TM_CCOEFF_NORMED)
if (win_check) > 0.8:
    print(win_check, lose_check)
    print('win')
    
elif lose_check > 0.8:
    print(win_check, lose_check)
    print('lose')
    
print(win_check, lose_check)
t2 = time.time()

print(t2 - t1)
# Out:
# [[0.9902859]] [[0.06141404]]
# win
# [[0.9902859]] [[0.06141404]]
# 0.2612192630767822

# %%
import numpy as np

# %%
img = pag.screenshot(region=(2830, 435, 55, 30))
img = np.array(img)
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
import cv2

# %%
pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/test1.png',region=(2830, 185, 55, 30))
screenshot = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/test1.png')
lose = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/cr_test/enemyWin.png')

# %%
type(lose)
# Out:
# numpy.ndarray

# %%
nocard = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/nocard.png')
nocard = cv2.cvtColor(nocard, cv2.COLOR_BGR2GRAY)
timeList = []
for i in range(10000):
    t1 = time.time()
    img = pag.screenshot(region = (2605, 100, 510, 900))
    img = np.array(img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    ratio = cv2.matchTemplate(nocard,img,cv2.TM_CCOEFF_NORMED)
    if(np.max(ratio) > 0.8):
        print(np.max(ratio))
        print("nocard")
        
    print(np.max(ratio))
    
    #print(np.max(ratio))
    t2 = time.time()
    time.sleep(0.5)
    timeList.append(t2-t1)
    
avg = sum(timeList, 0.0) / len(timeList)
print(avg)
# Out:
# 0.95539784
# nocard
# 0.9922578
# nocard
# 0.9806817
# nocard
# 0.92080003
# nocard
# 0.9713553
# nocard
# 0.96629703
# nocard
# 0.931406
# nocard
# 0.9219757
# nocard
# 0.92840797
# nocard
# 0.8903
# nocard
# 0.91621447
# nocard
# 0.9011385
# nocard
# 0.9344664
# nocard
# 0.8493694
# nocard
# 0.90858316
# nocard
# 0.87758785
# nocard
# 0.92954856
# nocard
# 0.9139842
# nocard
# 0.8783381
# nocard
# 0.862347
# nocard
# 0.91156447
# nocard
# 0.9277501
# nocard
# 0.8950752
# nocard
# 0.81105536
# nocard
# 0.9835852
# nocard
# 0.94120586
# nocard
# 0.9693916
# nocard
# 0.9417327
# nocard
# 0.9888193
# nocard
# 0.9635065
# nocard
# 0.9139183
# nocard
# 0.9189986
# nocard
# 0.9222624
# nocard
# 0.8546747
# nocard
# 0.9404119
# nocard
# 0.9343746
# nocard
# 0.92175263
# nocard
# 0.94236785
# nocard
# 0.98073596
# nocard
# 0.9410154
# nocard
# 0.95613486
# nocard
# 0.9040457
# nocard
# 0.9240427
# nocard
# 0.9314003
# nocard
# 0.98044527
# nocard
# 0.9607966
# nocard
# 0.94234335
# nocard
# ...

# %%
pag.click(1900, 425, button='left', clicks=1, interval=1)

# %%
import pyautogui as pag
screenshot_num = 0

# %%
from time import localtime
tm = localtime(time.time())

print(str(tm.tm_year) + str(tm.tm_mon) + str(tm.tm_mday) + '_' + str(tm.tm_hour) + str(tm.tm_min) + str(tm.tm_sec))
# Out:
# 202343_15754

# %%
import pyautogui as pag

pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/test2/'+ time.strftime('%Y-%m-%d_%H-%M-%S', time.localtime(time.time())) + '.png', region=(0, 0, 1920, 1080))

    
#width 490,height 875
screenshot_num += 1

# %%
time.strftime('%Y-%m-%d_%H-%M-%S', time.localtime(time.time()))
# Out:
# '2023-04-03_15-09-45'

# %%
import pyautogui as pag

pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/CR_'+ time.strftime('%Y-%m-%d_%H-%M-%S', time.localtime(time.time())) + '.png', region=(750, 125, 490, 875))

    
#width 490,height 875
screenshot_num += 1

# %%
time1 = time.time()
while(1):
    pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/CR_'+ time.strftime('%Y-%m-%d_%H-%M-%S', time.localtime(time.time())) + '.png', region=(750, 125, 490, 875))
    
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 5
#       2 while(1):
#       3     pag.screenshot('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/CR_'+ time.strftime('%Y-%m-%d_%H-%M-%S', time.localtime(time.time())) + '.png', region=(750, 125, 490, 875))
# ----> 5     time.sleep(1)
#
# KeyboardInterrupt:

# %%
#절대 누르지 말아야 할 위치 720, 790 / 810, 900

# %%
from gym import Env
from gym.spaces import Discrete, Box, MultiDiscrete
import numpy as np
import random

# %%
class ShowerEnv(Env):
    def __init__(self):
        # Actions we can take, down, stay, up
        self.action_space = Discrete(3)
        # Temperature array
        self.observation_space = Box(low=np.array([0]), high=np.array([100]))
        # Set start temp
        self.state = 38 + random.randint(-3,3)
        # Set shower length
        self.shower_length = 60
        
    def step(self, action):
        # Apply action
        # 0 -1 = -1 temperature
        # 1 -1 = 0 
        # 2 -1 = 1 temperature 
        self.state += action -1 
        # Reduce shower length by 1 second
        self.shower_length -= 1 
        
        # Calculate reward
        if self.state >= 37 and self.state <=39: 
            reward =1 
        else: r
            reward = -1 
        
        # Check if shower is done
        if self.shower_length <= 0: 
            done = True
        else:
            done = False
        
        # Apply temperature noise
        #self.state += random.randint(-1,1)
        # Set placeholder for info
        info = {}
        
        # Return step information
        return self.state, reward, done, info

    def render(self):
        # Implement viz
        pass
    
    def reset(self):
        # Reset shower temperature
        self.state = 38 + random.randint(-3,3)
        # Reset shower time
        self.shower_length = 60 
        return self.state

# %%
env = ShowerEnv()
# Out:
# /home/jnu/anaconda3/envs/torch_book/lib/python3.9/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")

# %%
env.observation_space.sample()
# Out:
# array([25.273743], dtype=float32)

# %%
class CREnv(Env):
    def __init__(self):
        self.action_space = MultiDiscrete([490, 875])
        # Temperature array
        self.observation_space = Box(low=0, high=255, shape=(490, 875, 3))
        # Set start temp
        self.state = 750 + random.randint(0, 490), 125 + random.int(0, 875)
        # Set shower length
    
    def step(self, action):
        x = action[0]
        y = action[1]
        
        
    def render(self):
        pass
        
    def reset(self):
        pass

# %%
import pyautogui as pag
import time
import random

start_time = time.time()
while(1):
    pag.click(750 + random.randint(0, 490), 125 + random.randint(0, 875), button='left', clicks=1)
    time.sleep(0.5)
    if(time.time() - start_time > 15):
        break
        
print("end macro")
# Out:
# end macro

# %%
"""
@author: Viet Nguyen <nhviet1009@gmail.com>
"""

import torch.nn as nn
import torch.nn.functional as F


class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(ActorCritic, self).__init__()
        self.conv1 = nn.Conv2d(num_inputs, 32, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv4 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.lstm = nn.LSTMCell(32 * 6 * 6, 512)
        self.critic_linear = nn.Linear(512, 1)
        self.actor_linear = nn.Linear(512, num_actions)
        self._initialize_weights()

    def _initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                # nn.init.kaiming_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTMCell):
                nn.init.constant_(module.bias_ih, 0)
                nn.init.constant_(module.bias_hh, 0)

    def forward(self, x, hx, cx):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        hx, cx = self.lstm(x.view(x.size(0), -1), (hx, cx))
        return self.actor_linear(hx), self.critic_linear(hx), hx, cx

# %%
from PIL import Image

imageA = '/home/jnu/Desktop/Reinforce/Royale/screenshot/test1_000'

imageB = Image.open(imageA)

# %%
imageB.show()

# %%
nn.Conv2d(num_inputs, 32, 3, stride=2, padding=1)

# %%
class ClickModel(nn.Module):
    def __init__(self, image, click_range):
        super().__init__()
        self.conv1 = nn.Conv2d(num_inputs, 32, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv4 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.lstm = nn.LSTMCell(32 * 6 * 6, 512)
        self.critic_linear = nn.Linear(512, 1)

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.autograd import Variable
import torch.nn.functional as F

import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
imageA = '/home/jnu/Desktop/Reinforce/Royale/screenshot/test1'

# %%
import os
train_o_fnames = os.listdir(imageA)
print(train_o_fnames)
# Out:
# ['CR_2023-04-03_15-16-16.png', 'CR_2023-04-03_15-15-43.png', 'CR_2023-04-03_15-16-39.png', 'CR_2023-04-03_15-15-47.png', 'CR_2023-04-03_15-14-36.png', 'CR_2023-04-03_15-16-28.png', 'CR_2023-04-03_15-14-32.png', 'CR_2023-04-03_15-14-42.png', 'CR_2023-04-03_15-15-04.png', 'CR_2023-04-03_15-12-13.png', 'CR_2023-04-03_15-16-38.png', 'CR_2023-04-03_15-12-27.png', 'CR_2023-04-03_15-12-30.png', 'CR_2023-04-03_15-15-24.png', 'CR_2023-04-03_15-14-05.png', 'CR_2023-04-03_15-14-52.png', 'CR_2023-04-03_15-14-51.png', 'CR_2023-04-03_15-15-56.png', 'CR_2023-04-03_15-15-52.png', 'CR_2023-04-03_15-17-03.png', 'CR_2023-04-03_15-13-54.png', 'CR_2023-04-03_15-12-29.png', 'CR_2023-04-03_15-16-07.png', 'CR_2023-04-03_15-14-49.png', 'CR_2023-04-03_15-14-28.png', 'CR_2023-04-03_15-14-44.png', 'CR_2023-04-03_15-17-00.png', 'CR_2023-04-03_15-16-26.png', 'CR_2023-04-03_15-13-55.png', 'CR_2023-04-03_15-12-25.png', 'CR_2023-04-03_15-13-59.png', 'CR_2023-04-03_15-16-43.png', 'CR_2023-04-03_15-15-57.png', 'CR_202
# ...

# %%
# 이미지 확인
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
ncols, nrows = 4, 2
fig = plt.gcf()
fig.set_size_inches(ncols*3, nrows*3)

next_o_pix = [os.path.join(imageA, fname) for fname in train_o_fnames[0:8]]

for i, img_path in enumerate(next_o_pix):
    sp = plt.subplot(nrows, ncols, i+1)
    sp.axis('OFF')
    img = mpimg.imread(img_path)
    plt.imshow(img)
    
plt.show()

# %%
import torch.nn as nn
import torch.nn.functional as F


class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(ActorCritic, self).__init__()
        self.conv1 = nn.Conv2d(num_inputs, 32, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv4 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.lstm = nn.LSTMCell(32 * 6 * 6, 512)
        self.critic_linear = nn.Linear(512, 1)
        self.actor_linear = nn.Linear(512, num_actions)
        self._initialize_weights()

    def _initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                # nn.init.kaiming_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTMCell):
                nn.init.constant_(module.bias_ih, 0)
                nn.init.constant_(module.bias_hh, 0)

    def forward(self, x, hx, cx):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        hx, cx = self.lstm(x.view(x.size(0), -1), (hx, cx))
        return self.actor_linear(hx), self.critic_linear(hx), hx, cx

# %%
import cv2
img_test = cv2.imread('/home/jnu/Desktop/Reinforce/Royale/screenshot/test1/CR_2023-04-03_15-17-00.png')
plt.imshow(img_test)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import cv2
import torch
import torch.nn.functional as F
import torch.nn as nn
from torchvision.transforms import ToTensor
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models

# %%
print(img_test.shape)
img_test = img_test.astype(np.uint8).copy()
# Out:
# (875, 490)

# %%
plt.imshow(img_test)

# %%
img_test.shape
# Out:
# (875, 490)

# %%
img_test = cv2.resize(img, (100, 100), interpolation=cv2.INTER_LINEAR)
img_test = ToTensor()(img).unsqueeze(0)
print(img_test.shape)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 img_test = cv2.resize(img, (100, 100), interpolation=cv2.INTER_LINEAR)
#       2 img_test = ToTensor()(img).unsqueeze(0)
#       3 print(img_test.shape)
#
# error: OpenCV(4.7.0) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'

# %%
import torch.nn as nn
import torch.nn.functional as F


class ActorCritic(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(ActorCritic, self).__init__()
        self.conv1 = nn.Conv2d(num_inputs, 32, 3, stride=2, padding=1)
        self.conv2 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv3 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.conv4 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
        self.lstm = nn.LSTMCell(32 * 6 * 6, 512)
        self.critic_linear = nn.Linear(512, 1)
        self.actor_linear = nn.Linear(512, num_actions)
        self._initialize_weights()

    def _initialize_weights(self):
        for module in self.modules():
            if isinstance(module, nn.Conv2d) or isinstance(module, nn.Linear):
                nn.init.xavier_uniform_(module.weight)
                # nn.init.kaiming_uniform_(module.weight)
                nn.init.constant_(module.bias, 0)
            elif isinstance(module, nn.LSTMCell):
                nn.init.constant_(module.bias_ih, 0)
                nn.init.constant_(module.bias_hh, 0)

    def forward(self, x, hx, cx):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        hx, cx = self.lstm(x.view(x.size(0), -1), (hx, cx))
        return self.actor_linear(hx), self.critic_linear(hx), hx, cx

# %%
num_state = img_test.astype(np.uint8).copy()
num_actions = 8

# %%
global_model = ActorCritic(num_state, num_actions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 global_model = ActorCritic(num_state, num_actions)
#
# Cell In[88], line 8, in ActorCritic.__init__(self, num_inputs, num_actions)
#       6 def __init__(self, num_inputs, num_actions):
#       7     super(ActorCritic, self).__init__()
# ----> 8     self.conv1 = nn.Conv2d(num_inputs, 32, 3, stride=2, padding=1)
#       9     self.conv2 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
#      10     self.conv3 = nn.Conv2d(32, 32, 3, stride=2, padding=1)
#
# File ~/anaconda3/envs/torch_book/lib/python3.9/site-packages/torch/nn/modules/conv.py:444, in Conv2d.__init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode, device, dtype)
#     442 padding_ = padding if isinstance(padding, str) else _pair(padding)
#     443 dilation_ = _pair(dilation)
# ...
